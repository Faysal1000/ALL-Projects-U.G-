# %%
# === System & OS Utilities ===
import os
import math
import pickle
import sys
import warnings
import random
import logging
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.ERROR)

# === Progress Bar ===
from tqdm import tqdm

# === TensorFlow & Keras ===
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adamax, AdamW
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.layers import Layer
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import (Conv2D, 
                                     Dense,
                                     Dropout,
                                     Flatten,
                                     GlobalAveragePooling2D,
                                     GlobalMaxPooling2D,
                                     MaxPooling2D,
                                     BatchNormalization,
                                     ReLU,
                                     Add)
from tensorflow.keras.layers import (
    Layer, Conv2D, Dense, Dropout,
    GlobalAveragePooling2D, GlobalMaxPooling2D,
    Reshape, Multiply, Add, Activation, Concatenate
)
import os, numpy as np, cv2
from skimage.feature import local_binary_pattern
from tensorflow.keras import layers, Model, initializers
from tensorflow.keras.layers import Layer
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Data Handling ===
import numpy as np
import pandas as pd
import cv2

# === Visualization ===
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# === Scikit-learn ===
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, classification_report, confusion_matrix
)

# %%
print("Python version:", sys.version)
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("OpenCV version:", cv2.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Python version: 3.11.14 (main, Oct 21 2025, 18:27:30) [Clang 20.1.8 ]
# TensorFlow version: 2.16.2
# Keras version: 3.5.0
# NumPy version: 1.26.4
# Pandas version: 2.2.3
# OpenCV version: 4.6.0
# Matplotlib version: 3.7.5
# Seaborn version: 0.12.2
# Scikit-learn version: 1.2.2

# %%
#python version 3.11.11
#!python -m pip install tensorflow==2.18.0 keras==3.5.0 numpy==1.26.4 pandas==2.2.3 opencv-python==4.6.0.66 matplotlib==3.7.5 seaborn==0.12.2 scikit-learn==1.2.2

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPUs detected: {len(gpus)}")
    except RuntimeError as e:
        print(f"Error setting GPU memory growth: {e}")
else:
    print("No GPUs detected.")
# Out:
# GPUs detected: 1

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
EPOCH = 100
img_shape=(*IMG_SIZE,3)
dataset_path = r"/kaggle/input/preprocessed-augmented-breakhis-dataset/preprocessed_breakhis_dataset/tissue_only_normalized"
labels = ['Benign', 'Malignant']
print("Class Names:", labels)
# Out:
# Class Names: ['Benign', 'Malignant']

# %%
def data_frame(root_path, target_folder):

    class_paths = []
    classes = []
    patient_ids = []

    for label in os.listdir(root_path):

        class_dir = os.path.join(root_path, label)
        if not os.path.isdir(class_dir):
            continue

        target_dir = os.path.join(class_dir, target_folder)

        if not os.path.isdir(target_dir):
            print(f"[WARNING] '{target_folder}' not found in class '{label}'. Skipping.")
            continue

        for image in os.listdir(target_dir):

            if not image.lower().endswith(('.png','.jpg','.jpeg')):
                continue

            path = os.path.join(target_dir,image)

            parts = image.split('-')

            # Skip malformed filenames
            if len(parts) < 3:
                print(f"Skipping malformed filename: {image}")
                continue

            patient_id = parts[1] + "-" + parts[2]

            class_paths.append(path)
            classes.append(label)
            patient_ids.append(patient_id)

    df = pd.DataFrame({
        'Class Path': class_paths,
        'Class': classes,
        'PatientID': patient_ids
    })

    return df

# %%
main_frame = data_frame(
    root_path=dataset_path,
    target_folder="400X"   # "40X", "100X", "200X", "400X"
)

patients = main_frame['PatientID'].unique()

train_pat, temp_pat = train_test_split(
    patients,
    test_size=0.20,
    random_state=42
)

val_pat, test_pat = train_test_split(
    temp_pat,
    test_size=0.5,
    random_state=42
)

train_dataframe = main_frame[main_frame['PatientID'].isin(train_pat)]
validation_dataframe = main_frame[main_frame['PatientID'].isin(val_pat)]
test_dataframe = main_frame[main_frame['PatientID'].isin(test_pat)]


print("Train patients:",len(set(train_dataframe.PatientID)))
print("Val patients:",len(set(validation_dataframe.PatientID)))
print("Test patients:",len(set(test_dataframe.PatientID)))

print("Overlap train-val:",set(train_dataframe.PatientID) & set(validation_dataframe.PatientID))
print("Overlap train-test:",set(train_dataframe.PatientID) & set(test_dataframe.PatientID))
print("Overlap val-test:",set(validation_dataframe.PatientID) & set(test_dataframe.PatientID))
print()
train_counts = train_dataframe['Class'].value_counts()
val_counts = validation_dataframe['Class'].value_counts()
test_counts = test_dataframe['Class'].value_counts()

count_table = pd.DataFrame({
    "Train": train_counts,
    "Validation": val_counts,
    "Test": test_counts
}).fillna(0).astype(int)

count_table["Total"] = count_table.sum(axis=1)
grand_total = pd.DataFrame({
    "Train": [count_table["Train"].sum()],
    "Validation": [count_table["Validation"].sum()],
    "Test": [count_table["Test"].sum()],
    "Total": [count_table["Total"].sum()]
}, index=["Total"])
count_table = pd.concat([count_table, grand_total])

print(count_table)

BATCH_SIZE = min(BATCH_SIZE, len(validation_dataframe))
print(f"Batch Size = {BATCH_SIZE}")
# Out:
# Train patients: 64
# Val patients: 8
# Test patients: 9
# Overlap train-val: set()
# Overlap train-test: set()
# Overlap val-test: set()
#
#            Train  Validation  Test  Total
# Benign      1252         186    62   1500
# Malignant   1134         142   224   1500
# Total       2386         328   286   3000
# Batch Size = 32

# %%
# Combine and sum the counts
total_counts = train_counts.add(val_counts, fill_value=0)
total_counts = total_counts.add(test_counts, fill_value=0)
total_counts = total_counts.sort_index()

# Prepare labels with percentages
total = total_counts.sum()
labels_with_percent = [f"{label} ({(count/total)*100:.1f}%)" for label, count in zip(total_counts.index, total_counts.values)]

# Define custom autopct function to show raw count
def make_autopct(values):
    def autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f"{count}"
    return autopct

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_counts.values, labels=labels_with_percent, autopct=make_autopct(total_counts.values), startangle=140, textprops={'fontsize': 12})
plt.axis('equal')
plt.show()

# %%
# Count occurrences of each class in train, validation, and test datasets
train_counts = train_dataframe['Class'].value_counts().sort_index()
val_counts = validation_dataframe['Class'].value_counts().sort_index()
test_counts = test_dataframe['Class'].value_counts().sort_index()

# Combine into a DataFrame with the index kept as a column
data_counts = pd.DataFrame({
    'Class': train_counts.index,
    'Train': train_counts.values,
    'Validation': val_counts.values,
    'Test': test_counts.values
}).melt(id_vars='Class', var_name='Dataset', value_name='Count')

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(y='Class', x='Count', hue='Dataset', data=data_counts, 
                 palette=['blue', 'orange', 'green'], orient='h', width=0.6)

# Add count labels to the right of the bars with slight downward offset
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', 
                (p.get_width(), p.get_y() + p.get_height() / 2.0 + 0.05),  # pushed slightly down
                ha='left', va='center', 
                fontsize=10, color='black', 
                xytext=(5, 0), textcoords='offset points')

# Remove borders (spines)
sns.despine(top=True, right=True, left=False, bottom=False)

# Dynamically set the x-axis limits with some extra space on the right
left, right = ax.get_xlim()  # Get current x-limits

# Set the new right limit with a 15% increase
right += (right - left) * 0.15  # Increase right by 15%

# Apply the new limits to the x-axis
ax.set_xlim(left, right)

# Add labels and title
plt.ylabel("Class")
plt.xlabel("Count")
plt.title("Class Distribution in Train, Validation, and Test Sets")

# Move the legend
plt.legend(title="Dataset", loc='upper right', fontsize=8)

# Add grid only along x-axis
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Tidy layout
plt.tight_layout()
plt.show()

# %%
def preprocess_image(image):

    image = image.astype(np.float32)

    min_val = image.min()
    max_val = image.max()

    # avoid division by zero
    if max_val - min_val < 1e-6:
        return np.zeros_like(image, dtype=np.float32)

    # min-max scale to [0, 1]
    image = (image - min_val) / (max_val - min_val)
    
    return image

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,

    # ---- Geometric ----
    rotation_range=30,         
    zoom_range=0.1,           
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,

    horizontal_flip=True,
    vertical_flip=True,

    fill_mode="reflect"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)


train_data = train_datagen.flow_from_dataframe(train_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', seed=42)

validation_data = val_datagen.flow_from_dataframe(validation_dataframe, x_col='Class Path',
                                     y_col='Class', batch_size=BATCH_SIZE,
                                     target_size=IMG_SIZE, class_mode='binary', seed=42)

test_data = test_datagen.flow_from_dataframe(test_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', shuffle=False, seed=42)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.

# %%
class RestoreBestValidationModel(Callback):
    """
    Custom Keras Callback to restore model weights from the best epoch based on validation accuracy.
    - Tracks the best validation accuracy during training.
    - Restores the model weights from the epoch with the best validation accuracy when training finishes.
    """
    
    def __init__(self):
        super(RestoreBestValidationModel, self).__init__()
        # Initialize best validation accuracy, epoch, and weights to track the best model
        self.best_val_acc = -1
        self.best_epoch = -1
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        """
        Callback function executed at the end of each epoch.
        - Compares the current validation accuracy with the best validation accuracy.
        - If the current validation accuracy is higher or tied but at a later epoch, updates the best model weights.
        """
        # Get validation accuracy from logs
        val_acc = logs.get('val_accuracy')
        
        if val_acc is not None:
            # Update the best validation accuracy and weights if the current one is better or at a later epoch
            if val_acc > self.best_val_acc or (val_acc == self.best_val_acc and epoch > self.best_epoch):
                self.best_val_acc = val_acc
                self.best_epoch = epoch
                self.best_weights = self.model.get_weights()  # Store the model's weights
                print(f"\nModel weights updated at epoch {epoch + 1} with val_accuracy: {val_acc:.4f}")

    def on_train_end(self, logs=None):
        """
        Callback function executed at the end of training.
        - Restores the model weights from the epoch with the best validation accuracy.
        """
        # If we found a better model during training, restore the best weights
        if self.best_weights is not None:
            print(f"Restoring model weights from best epoch {self.best_epoch + 1} with val_accuracy: {self.best_val_acc:.4f}")
            self.model.set_weights(self.best_weights)  # Set the weights back to the best model's weights

# Instantiate the callback
restore_best = RestoreBestValidationModel()

# %%
base_model = tf.keras.applications.MobileNetV3Large(
    input_shape=(224, 224, 3),
    include_top=False,
    weights=None
)

x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)  # optional hidden layer....
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)  
model = tf.keras.Model(inputs=base_model.input, outputs=output)
# Out:
# I0000 00:00:1772989112.269763      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# ===============================
# Dynamic Cosine Decay
# ===============================
num_train_samples = sum(list(train_counts))

steps_per_epoch = math.ceil(num_train_samples / BATCH_SIZE)
decay_steps = steps_per_epoch * EPOCH

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4,
    decay_steps=decay_steps,
    alpha=1e-3   
)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=5e-5,   
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-7
)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=[
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

print("Model compiled with optimized AdamW + CosineDecay")
print(f"Train samples: {num_train_samples}")
print(f"Steps per epoch: {steps_per_epoch}")
print(f"Total decay steps: {decay_steps}")
# Out:
# Model compiled with optimized AdamW + CosineDecay
# Train samples: 2400
# Steps per epoch: 75
# Total decay steps: 7500

# %%
all_steps = np.arange(decay_steps)
lrs = [lr_schedule(step).numpy() for step in all_steps]

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(8,4))
plt.plot(all_steps, lrs)
plt.title("Cosine Decay Learning Rate Schedule")
plt.xlabel("Training Steps")
plt.ylabel("Learning Rate")
plt.grid(True)
plt.show()

# %%
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=EPOCH,
    callbacks=[restore_best],
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772989164.695463     104 service.cc:148] XLA service 0x7def98192bd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772989164.697382     104 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772989169.865486     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1772989176.629867     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772989176.815339     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772989177.257101     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772989177.454451     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  1/75 ━━━━━━━━━━━━━━━━━━━━ 1:18:59 64s/step - accuracy: 0.5000 - auc: 0.3941 - loss: 0.7043 - precision: 0.4815 - recall: 0.8667
# I0000 00:00:1772989193.965026     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.6359 - auc: 0.6801 - loss: 0.6394 - precision: 0.6267 - recall: 0.7289
# Model weights updated at epoch 1 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 641ms/step - accuracy: 0.6365 - auc: 0.6809 - loss: 0.6389 - precision: 0.6272 - recall: 0.7287 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.7604 - auc: 0.8356 - loss: 0.5061 - precision: 0.7644 - recall: 0.7371
# Model weights updated at epoch 2 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 429ms/step - accuracy: 0.7604 - auc: 0.8355 - loss: 0.5061 - precision: 0.7645 - recall: 0.7371 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.7655 - auc: 0.8441 - loss: 0.4888 - precision: 0.7782 - recall: 0.7542
# Model weights updated at epoch 3 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 423ms/step - accuracy: 0.7654 - auc: 0.8441 - loss: 0.4889 - precision: 0.7780 - recall: 0.7542 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.7716 - auc: 0.8597 - loss: 0.4705 - precision: 0.7745 - recall: 0.7541
# Model weights updated at epoch 4 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 422ms/step - accuracy: 0.7716 - auc: 0.8596 - loss: 0.4706 - precision: 0.7745 - recall: 0.7543 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7767 - auc: 0.8573 - loss: 0.4708 - precision: 0.7482 - recall: 0.8257
# Model weights updated at epoch 5 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.7768 - auc: 0.8574 - loss: 0.4707 - precision: 0.7484 - recall: 0.8256 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.7853 - auc: 0.8559 - loss: 0.4692 - precision: 0.7758 - recall: 0.8161
# Model weights updated at epoch 6 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.7853 - auc: 0.8560 - loss: 0.4692 - precision: 0.7757 - recall: 0.8163 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.7825 - auc: 0.8665 - loss: 0.4555 - precision: 0.7763 - recall: 0.7932
# Model weights updated at epoch 7 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.7824 - auc: 0.8665 - loss: 0.4555 - precision: 0.7761 - recall: 0.7933 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.8112 - auc: 0.8790 - loss: 0.4269 - precision: 0.7736 - recall: 0.8794
# Model weights updated at epoch 8 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.8112 - auc: 0.8790 - loss: 0.4270 - precision: 0.7737 - recall: 0.8792 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8066 - auc: 0.8879 - loss: 0.4175 - precision: 0.7835 - recall: 0.8380
# Model weights updated at epoch 9 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.8065 - auc: 0.8879 - loss: 0.4176 - precision: 0.7834 - recall: 0.8379 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.8010 - auc: 0.8837 - loss: 0.4308 - precision: 0.7766 - recall: 0.8394
# Model weights updated at epoch 10 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.8010 - auc: 0.8838 - loss: 0.4306 - precision: 0.7766 - recall: 0.8394 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.7947 - auc: 0.8892 - loss: 0.4097 - precision: 0.7625 - recall: 0.8586
# Model weights updated at epoch 11 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.7949 - auc: 0.8893 - loss: 0.4096 - precision: 0.7626 - recall: 0.8585 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8047 - auc: 0.8941 - loss: 0.4123 - precision: 0.7700 - recall: 0.8541
# Model weights updated at epoch 12 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.8049 - auc: 0.8942 - loss: 0.4121 - precision: 0.7703 - recall: 0.8543 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.8374 - auc: 0.9135 - loss: 0.3725 - precision: 0.8218 - recall: 0.8601
# Model weights updated at epoch 13 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 402ms/step - accuracy: 0.8372 - auc: 0.9134 - loss: 0.3727 - precision: 0.8217 - recall: 0.8599 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6934 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8141 - auc: 0.9022 - loss: 0.3937 - precision: 0.7864 - recall: 0.8557
# Model weights updated at epoch 14 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.8142 - auc: 0.9023 - loss: 0.3935 - precision: 0.7867 - recall: 0.8555 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.8293 - auc: 0.9156 - loss: 0.3713 - precision: 0.8076 - recall: 0.8561
# Model weights updated at epoch 15 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 33s 445ms/step - accuracy: 0.8293 - auc: 0.9155 - loss: 0.3714 - precision: 0.8076 - recall: 0.8561 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8369 - auc: 0.9231 - loss: 0.3502 - precision: 0.8226 - recall: 0.8551
# Model weights updated at epoch 16 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 421ms/step - accuracy: 0.8368 - auc: 0.9230 - loss: 0.3504 - precision: 0.8226 - recall: 0.8549 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8427 - auc: 0.9276 - loss: 0.3403 - precision: 0.8427 - recall: 0.8552
# Model weights updated at epoch 17 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.8427 - auc: 0.9276 - loss: 0.3404 - precision: 0.8425 - recall: 0.8552 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6931 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8226 - auc: 0.9147 - loss: 0.3657 - precision: 0.8131 - recall: 0.8411
# Model weights updated at epoch 18 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.8227 - auc: 0.9148 - loss: 0.3654 - precision: 0.8132 - recall: 0.8413 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6933 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.8418 - auc: 0.9260 - loss: 0.3434 - precision: 0.8294 - recall: 0.8425
# Model weights updated at epoch 19 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.8419 - auc: 0.9260 - loss: 0.3435 - precision: 0.8296 - recall: 0.8427 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6937 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8489 - auc: 0.9327 - loss: 0.3324 - precision: 0.8449 - recall: 0.8514
# Model weights updated at epoch 20 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 395ms/step - accuracy: 0.8488 - auc: 0.9326 - loss: 0.3326 - precision: 0.8448 - recall: 0.8514 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6940 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8501 - auc: 0.9304 - loss: 0.3331 - precision: 0.8479 - recall: 0.8519
# Model weights updated at epoch 21 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 393ms/step - accuracy: 0.8502 - auc: 0.9305 - loss: 0.3330 - precision: 0.8480 - recall: 0.8521 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8487 - auc: 0.9370 - loss: 0.3187 - precision: 0.8389 - recall: 0.8663
# Model weights updated at epoch 22 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.8488 - auc: 0.9370 - loss: 0.3187 - precision: 0.8390 - recall: 0.8663 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6943 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8452 - auc: 0.9286 - loss: 0.3416 - precision: 0.8393 - recall: 0.8585
# Model weights updated at epoch 23 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 424ms/step - accuracy: 0.8453 - auc: 0.9287 - loss: 0.3413 - precision: 0.8394 - recall: 0.8586 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6956 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8630 - auc: 0.9399 - loss: 0.3131 - precision: 0.8745 - recall: 0.8507
# Model weights updated at epoch 24 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 402ms/step - accuracy: 0.8629 - auc: 0.9399 - loss: 0.3133 - precision: 0.8743 - recall: 0.8506 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6944 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8577 - auc: 0.9364 - loss: 0.3201 - precision: 0.8465 - recall: 0.8744
# Model weights updated at epoch 25 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.8576 - auc: 0.9364 - loss: 0.3201 - precision: 0.8465 - recall: 0.8743 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6944 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.8746 - auc: 0.9485 - loss: 0.2905 - precision: 0.8714 - recall: 0.8733
# Model weights updated at epoch 26 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.8745 - auc: 0.9484 - loss: 0.2907 - precision: 0.8713 - recall: 0.8731 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6963 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8667 - auc: 0.9438 - loss: 0.3030 - precision: 0.8612 - recall: 0.8693
# Model weights updated at epoch 27 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 393ms/step - accuracy: 0.8668 - auc: 0.9438 - loss: 0.3029 - precision: 0.8613 - recall: 0.8694 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6967 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8580 - auc: 0.9386 - loss: 0.3140 - precision: 0.8468 - recall: 0.8765
# Model weights updated at epoch 28 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.8580 - auc: 0.9387 - loss: 0.3139 - precision: 0.8468 - recall: 0.8764 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7009 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8740 - auc: 0.9474 - loss: 0.2946 - precision: 0.8874 - recall: 0.8557
# Model weights updated at epoch 29 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.8739 - auc: 0.9474 - loss: 0.2947 - precision: 0.8871 - recall: 0.8558 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.6997 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.8721 - auc: 0.9501 - loss: 0.2859 - precision: 0.8767 - recall: 0.8619
# Model weights updated at epoch 30 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.8721 - auc: 0.9501 - loss: 0.2859 - precision: 0.8766 - recall: 0.8620 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7039 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.8658 - auc: 0.9433 - loss: 0.3018 - precision: 0.8580 - recall: 0.8786
# Model weights updated at epoch 31 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 397ms/step - accuracy: 0.8658 - auc: 0.9433 - loss: 0.3018 - precision: 0.8580 - recall: 0.8786 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7067 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8766 - auc: 0.9555 - loss: 0.2733 - precision: 0.8855 - recall: 0.8698
# Model weights updated at epoch 32 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.8766 - auc: 0.9554 - loss: 0.2733 - precision: 0.8854 - recall: 0.8699 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7138 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.8872 - auc: 0.9604 - loss: 0.2552 - precision: 0.8745 - recall: 0.8924
# Model weights updated at epoch 33 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.8871 - auc: 0.9603 - loss: 0.2555 - precision: 0.8745 - recall: 0.8923 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7149 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8867 - auc: 0.9586 - loss: 0.2601 - precision: 0.8865 - recall: 0.8903
# Model weights updated at epoch 34 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.8865 - auc: 0.9585 - loss: 0.2602 - precision: 0.8864 - recall: 0.8902 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7179 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.8907 - auc: 0.9587 - loss: 0.2605 - precision: 0.8901 - recall: 0.8929
# Model weights updated at epoch 35 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.8906 - auc: 0.9586 - loss: 0.2607 - precision: 0.8899 - recall: 0.8929 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7176 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8947 - auc: 0.9598 - loss: 0.2566 - precision: 0.8964 - recall: 0.8920
# Model weights updated at epoch 36 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.8946 - auc: 0.9597 - loss: 0.2568 - precision: 0.8963 - recall: 0.8917 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7250 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.8936 - auc: 0.9623 - loss: 0.2486 - precision: 0.8955 - recall: 0.8904
# Model weights updated at epoch 37 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 399ms/step - accuracy: 0.8935 - auc: 0.9622 - loss: 0.2487 - precision: 0.8954 - recall: 0.8903 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7305 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9055 - auc: 0.9617 - loss: 0.2533 - precision: 0.8998 - recall: 0.9088
# Model weights updated at epoch 38 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.9053 - auc: 0.9617 - loss: 0.2535 - precision: 0.8996 - recall: 0.9087 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7433 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.8892 - auc: 0.9654 - loss: 0.2395 - precision: 0.8820 - recall: 0.8902
# Model weights updated at epoch 39 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 394ms/step - accuracy: 0.8892 - auc: 0.9654 - loss: 0.2398 - precision: 0.8820 - recall: 0.8902 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7391 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8938 - auc: 0.9624 - loss: 0.2487 - precision: 0.9029 - recall: 0.8823
# Model weights updated at epoch 40 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.8939 - auc: 0.9624 - loss: 0.2486 - precision: 0.9028 - recall: 0.8825 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7599 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8828 - auc: 0.9560 - loss: 0.2650 - precision: 0.8978 - recall: 0.8631
# Model weights updated at epoch 41 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.8829 - auc: 0.9561 - loss: 0.2648 - precision: 0.8978 - recall: 0.8634 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7671 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.8850 - auc: 0.9624 - loss: 0.2480 - precision: 0.8916 - recall: 0.8835
# Model weights updated at epoch 42 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.8850 - auc: 0.9624 - loss: 0.2479 - precision: 0.8915 - recall: 0.8836 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7792 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8953 - auc: 0.9654 - loss: 0.2368 - precision: 0.9026 - recall: 0.8831
# Model weights updated at epoch 43 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 427ms/step - accuracy: 0.8953 - auc: 0.9654 - loss: 0.2367 - precision: 0.9026 - recall: 0.8832 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7745 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8864 - auc: 0.9618 - loss: 0.2493 - precision: 0.8980 - recall: 0.8731
# Model weights updated at epoch 44 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.8866 - auc: 0.9619 - loss: 0.2491 - precision: 0.8980 - recall: 0.8733 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7929 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.8908 - auc: 0.9664 - loss: 0.2345 - precision: 0.9030 - recall: 0.8811
# Model weights updated at epoch 45 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 402ms/step - accuracy: 0.8909 - auc: 0.9663 - loss: 0.2346 - precision: 0.9029 - recall: 0.8812 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7775 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9038 - auc: 0.9663 - loss: 0.2348 - precision: 0.9205 - recall: 0.8914
# Model weights updated at epoch 46 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9039 - auc: 0.9664 - loss: 0.2346 - precision: 0.9204 - recall: 0.8915 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8097 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9007 - auc: 0.9678 - loss: 0.2290 - precision: 0.9017 - recall: 0.9009
# Model weights updated at epoch 47 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9007 - auc: 0.9678 - loss: 0.2290 - precision: 0.9017 - recall: 0.9010 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8374 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9126 - auc: 0.9733 - loss: 0.2097 - precision: 0.9322 - recall: 0.8821
# Model weights updated at epoch 48 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 405ms/step - accuracy: 0.9124 - auc: 0.9732 - loss: 0.2100 - precision: 0.9320 - recall: 0.8821 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.7976 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9102 - auc: 0.9745 - loss: 0.2069 - precision: 0.9023 - recall: 0.9154
# Model weights updated at epoch 49 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 397ms/step - accuracy: 0.9101 - auc: 0.9745 - loss: 0.2069 - precision: 0.9024 - recall: 0.9153 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8546 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9089 - auc: 0.9743 - loss: 0.2062 - precision: 0.9162 - recall: 0.9025
# Model weights updated at epoch 50 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9089 - auc: 0.9742 - loss: 0.2063 - precision: 0.9162 - recall: 0.9024 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8525 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9026 - auc: 0.9706 - loss: 0.2184 - precision: 0.9124 - recall: 0.8932
# Model weights updated at epoch 51 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 403ms/step - accuracy: 0.9026 - auc: 0.9706 - loss: 0.2183 - precision: 0.9124 - recall: 0.8933 - val_accuracy: 0.5000 - val_auc: 0.3467 - val_loss: 0.8562 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.9120 - auc: 0.9723 - loss: 0.2091 - precision: 0.9209 - recall: 0.8927
# Model weights updated at epoch 52 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 399ms/step - accuracy: 0.9119 - auc: 0.9723 - loss: 0.2093 - precision: 0.9208 - recall: 0.8928 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8504 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9094 - auc: 0.9741 - loss: 0.2088 - precision: 0.9148 - recall: 0.8964
# Model weights updated at epoch 53 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.9093 - auc: 0.9741 - loss: 0.2089 - precision: 0.9148 - recall: 0.8964 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8778 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9066 - auc: 0.9707 - loss: 0.2207 - precision: 0.9232 - recall: 0.8841
# Model weights updated at epoch 54 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.9067 - auc: 0.9707 - loss: 0.2206 - precision: 0.9232 - recall: 0.8843 - val_accuracy: 0.5000 - val_auc: 0.3600 - val_loss: 0.8715 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9147 - auc: 0.9735 - loss: 0.2082 - precision: 0.9270 - recall: 0.9006
# Model weights updated at epoch 55 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.9147 - auc: 0.9735 - loss: 0.2080 - precision: 0.9270 - recall: 0.9007 - val_accuracy: 0.5000 - val_auc: 0.4867 - val_loss: 0.9031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9191 - auc: 0.9773 - loss: 0.1932 - precision: 0.9177 - recall: 0.9165
# Model weights updated at epoch 56 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9190 - auc: 0.9773 - loss: 0.1933 - precision: 0.9176 - recall: 0.9164 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8613 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9211 - auc: 0.9800 - loss: 0.1819 - precision: 0.9242 - recall: 0.9193
# Model weights updated at epoch 57 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 405ms/step - accuracy: 0.9210 - auc: 0.9799 - loss: 0.1821 - precision: 0.9242 - recall: 0.9192 - val_accuracy: 0.5000 - val_auc: 0.5167 - val_loss: 0.8963 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9085 - auc: 0.9721 - loss: 0.2110 - precision: 0.9182 - recall: 0.8956
# Model weights updated at epoch 58 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 394ms/step - accuracy: 0.9086 - auc: 0.9721 - loss: 0.2108 - precision: 0.9183 - recall: 0.8957 - val_accuracy: 0.5000 - val_auc: 0.4333 - val_loss: 0.9048 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9113 - auc: 0.9745 - loss: 0.2076 - precision: 0.9137 - recall: 0.9070
# Model weights updated at epoch 59 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 403ms/step - accuracy: 0.9113 - auc: 0.9745 - loss: 0.2076 - precision: 0.9137 - recall: 0.9070 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 0.8842 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9102 - auc: 0.9761 - loss: 0.1973 - precision: 0.9263 - recall: 0.8960
# Model weights updated at epoch 60 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 408ms/step - accuracy: 0.9103 - auc: 0.9761 - loss: 0.1974 - precision: 0.9261 - recall: 0.8961 - val_accuracy: 0.5000 - val_auc: 0.4300 - val_loss: 0.9325 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9135 - auc: 0.9798 - loss: 0.1869 - precision: 0.9327 - recall: 0.8947
# Model weights updated at epoch 61 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 403ms/step - accuracy: 0.9135 - auc: 0.9798 - loss: 0.1870 - precision: 0.9326 - recall: 0.8948 - val_accuracy: 0.5000 - val_auc: 0.6412 - val_loss: 0.8797 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9142 - auc: 0.9803 - loss: 0.1801 - precision: 0.9129 - recall: 0.9152
# Model weights updated at epoch 62 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9143 - auc: 0.9803 - loss: 0.1802 - precision: 0.9130 - recall: 0.9151 - val_accuracy: 0.5000 - val_auc: 0.4567 - val_loss: 0.8441 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9264 - auc: 0.9826 - loss: 0.1730 - precision: 0.9212 - recall: 0.9318
# Model weights updated at epoch 63 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9263 - auc: 0.9826 - loss: 0.1731 - precision: 0.9212 - recall: 0.9317 - val_accuracy: 0.5000 - val_auc: 0.3876 - val_loss: 0.8376 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9235 - auc: 0.9803 - loss: 0.1783 - precision: 0.9265 - recall: 0.9192
# Model weights updated at epoch 64 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9235 - auc: 0.9803 - loss: 0.1784 - precision: 0.9265 - recall: 0.9191 - val_accuracy: 0.5000 - val_auc: 0.4328 - val_loss: 0.8379 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9300 - auc: 0.9839 - loss: 0.1653 - precision: 0.9338 - recall: 0.9231
# Model weights updated at epoch 65 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.9299 - auc: 0.9838 - loss: 0.1655 - precision: 0.9337 - recall: 0.9230 - val_accuracy: 0.5000 - val_auc: 0.6706 - val_loss: 0.8160 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9273 - auc: 0.9849 - loss: 0.1618 - precision: 0.9246 - recall: 0.9286
# Model weights updated at epoch 66 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.9272 - auc: 0.9849 - loss: 0.1621 - precision: 0.9247 - recall: 0.9284 - val_accuracy: 0.5000 - val_auc: 0.2896 - val_loss: 0.8453 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9296 - auc: 0.9816 - loss: 0.1745 - precision: 0.9330 - recall: 0.9276
# Model weights updated at epoch 67 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.9295 - auc: 0.9816 - loss: 0.1746 - precision: 0.9330 - recall: 0.9275 - val_accuracy: 0.5000 - val_auc: 0.7718 - val_loss: 0.8037 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9283 - auc: 0.9799 - loss: 0.1822 - precision: 0.9406 - recall: 0.9207
# Model weights updated at epoch 68 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 395ms/step - accuracy: 0.9283 - auc: 0.9799 - loss: 0.1821 - precision: 0.9406 - recall: 0.9207 - val_accuracy: 0.5000 - val_auc: 0.7529 - val_loss: 0.6930 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9246 - auc: 0.9814 - loss: 0.1767 - precision: 0.9228 - recall: 0.9203
# Model weights updated at epoch 69 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9246 - auc: 0.9814 - loss: 0.1767 - precision: 0.9229 - recall: 0.9203 - val_accuracy: 0.5000 - val_auc: 0.7399 - val_loss: 0.7852 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9269 - auc: 0.9798 - loss: 0.1819 - precision: 0.9243 - recall: 0.9295
# Model weights updated at epoch 70 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9269 - auc: 0.9798 - loss: 0.1818 - precision: 0.9243 - recall: 0.9295 - val_accuracy: 0.5000 - val_auc: 0.5760 - val_loss: 0.8535 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9240 - auc: 0.9828 - loss: 0.1686 - precision: 0.9297 - recall: 0.9180
# Model weights updated at epoch 71 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9241 - auc: 0.9828 - loss: 0.1685 - precision: 0.9297 - recall: 0.9181 - val_accuracy: 0.5000 - val_auc: 0.4742 - val_loss: 0.8524 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9303 - auc: 0.9821 - loss: 0.1743 - precision: 0.9315 - recall: 0.9281
# Model weights updated at epoch 72 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.9303 - auc: 0.9821 - loss: 0.1742 - precision: 0.9315 - recall: 0.9281 - val_accuracy: 0.5000 - val_auc: 0.6849 - val_loss: 0.9230 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9218 - auc: 0.9814 - loss: 0.1746 - precision: 0.9285 - recall: 0.9093
# Model weights updated at epoch 73 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 402ms/step - accuracy: 0.9219 - auc: 0.9814 - loss: 0.1745 - precision: 0.9286 - recall: 0.9095 - val_accuracy: 0.5000 - val_auc: 0.5896 - val_loss: 0.7983 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9319 - auc: 0.9848 - loss: 0.1594 - precision: 0.9469 - recall: 0.9160
# Model weights updated at epoch 74 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9319 - auc: 0.9848 - loss: 0.1594 - precision: 0.9468 - recall: 0.9161 - val_accuracy: 0.5000 - val_auc: 0.4684 - val_loss: 0.9536 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9278 - auc: 0.9848 - loss: 0.1591 - precision: 0.9406 - recall: 0.9170
# Model weights updated at epoch 75 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9279 - auc: 0.9848 - loss: 0.1591 - precision: 0.9405 - recall: 0.9171 - val_accuracy: 0.5000 - val_auc: 0.4565 - val_loss: 0.8251 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9243 - auc: 0.9835 - loss: 0.1655 - precision: 0.9360 - recall: 0.9105
# Model weights updated at epoch 76 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9244 - auc: 0.9835 - loss: 0.1654 - precision: 0.9360 - recall: 0.9107 - val_accuracy: 0.5000 - val_auc: 0.6788 - val_loss: 0.8771 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 419ms/step - accuracy: 0.9290 - auc: 0.9833 - loss: 0.1662 - precision: 0.9365 - recall: 0.9199 - val_accuracy: 0.4967 - val_auc: 0.6085 - val_loss: 0.6999 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9403 - auc: 0.9863 - loss: 0.1536 - precision: 0.9489 - recall: 0.9328
# Model weights updated at epoch 78 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 405ms/step - accuracy: 0.9402 - auc: 0.9863 - loss: 0.1537 - precision: 0.9489 - recall: 0.9328 - val_accuracy: 0.5000 - val_auc: 0.5863 - val_loss: 0.7757 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9363 - auc: 0.9878 - loss: 0.1443 - precision: 0.9516 - recall: 0.9180
# Model weights updated at epoch 79 with val_accuracy: 0.5100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.9363 - auc: 0.9878 - loss: 0.1443 - precision: 0.9515 - recall: 0.9181 - val_accuracy: 0.5100 - val_auc: 0.5302 - val_loss: 0.7064 - val_precision: 0.8000 - val_recall: 0.0267
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9470 - auc: 0.9875 - loss: 0.1426 - precision: 0.9569 - recall: 0.9354
# Model weights updated at epoch 80 with val_accuracy: 0.5133
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 402ms/step - accuracy: 0.9469 - auc: 0.9875 - loss: 0.1427 - precision: 0.9568 - recall: 0.9354 - val_accuracy: 0.5133 - val_auc: 0.5533 - val_loss: 0.6890 - val_precision: 0.5080 - val_recall: 0.8467
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 408ms/step - accuracy: 0.9269 - auc: 0.9837 - loss: 0.1625 - precision: 0.9293 - recall: 0.9192 - val_accuracy: 0.5000 - val_auc: 0.6603 - val_loss: 1.4187 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 405ms/step - accuracy: 0.9394 - auc: 0.9887 - loss: 0.1409 - precision: 0.9334 - recall: 0.9451 - val_accuracy: 0.5000 - val_auc: 0.5507 - val_loss: 1.6091 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9440 - auc: 0.9869 - loss: 0.1486 - precision: 0.9425 - recall: 0.9445
# Model weights updated at epoch 83 with val_accuracy: 0.5200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.9438 - auc: 0.9869 - loss: 0.1487 - precision: 0.9425 - recall: 0.9443 - val_accuracy: 0.5200 - val_auc: 0.6546 - val_loss: 0.7391 - val_precision: 0.5104 - val_recall: 0.9800
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9401 - auc: 0.9869 - loss: 0.1493 - precision: 0.9394 - recall: 0.9372 - val_accuracy: 0.5000 - val_auc: 0.6675 - val_loss: 0.9709 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 392ms/step - accuracy: 0.9457 - auc: 0.9884 - loss: 0.1400 - precision: 0.9479 - recall: 0.9465 - val_accuracy: 0.5000 - val_auc: 0.6401 - val_loss: 1.1665 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.9449 - auc: 0.9886 - loss: 0.1374 - precision: 0.9535 - recall: 0.9340 - val_accuracy: 0.5000 - val_auc: 0.5670 - val_loss: 1.5969 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.9431 - auc: 0.9864 - loss: 0.1487 - precision: 0.9531 - recall: 0.9333 - val_accuracy: 0.5000 - val_auc: 0.6371 - val_loss: 1.7407 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9336 - auc: 0.9836 - loss: 0.1600 - precision: 0.9420 - recall: 0.9260 - val_accuracy: 0.5000 - val_auc: 0.5392 - val_loss: 1.8373 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.9356 - auc: 0.9868 - loss: 0.1493 - precision: 0.9466 - recall: 0.9255 - val_accuracy: 0.4967 - val_auc: 0.5514 - val_loss: 1.9216 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 398ms/step - accuracy: 0.9470 - auc: 0.9895 - loss: 0.1319 - precision: 0.9486 - recall: 0.9437 - val_accuracy: 0.4967 - val_auc: 0.5161 - val_loss: 2.0682 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 394ms/step - accuracy: 0.9410 - auc: 0.9890 - loss: 0.1353 - precision: 0.9477 - recall: 0.9330 - val_accuracy: 0.4933 - val_auc: 0.4817 - val_loss: 2.2780 - val_precision: 0.4966 - val_recall: 0.9867
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 397ms/step - accuracy: 0.9427 - auc: 0.9876 - loss: 0.1427 - precision: 0.9459 - recall: 0.9392 - val_accuracy: 0.4867 - val_auc: 0.4348 - val_loss: 2.4546 - val_precision: 0.4932 - val_recall: 0.9733
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.9253 - auc: 0.9864 - loss: 0.1517 - precision: 0.9215 - recall: 0.9255 - val_accuracy: 0.4867 - val_auc: 0.4262 - val_loss: 2.5686 - val_precision: 0.4932 - val_recall: 0.9733
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 399ms/step - accuracy: 0.9368 - auc: 0.9845 - loss: 0.1602 - precision: 0.9436 - recall: 0.9317 - val_accuracy: 0.4833 - val_auc: 0.4116 - val_loss: 2.5563 - val_precision: 0.4915 - val_recall: 0.9667
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 399ms/step - accuracy: 0.9405 - auc: 0.9888 - loss: 0.1400 - precision: 0.9486 - recall: 0.9357 - val_accuracy: 0.4800 - val_auc: 0.4092 - val_loss: 2.4902 - val_precision: 0.4898 - val_recall: 0.9600
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 403ms/step - accuracy: 0.9339 - auc: 0.9858 - loss: 0.1540 - precision: 0.9240 - recall: 0.9400 - val_accuracy: 0.4667 - val_auc: 0.4170 - val_loss: 2.4052 - val_precision: 0.4828 - val_recall: 0.9333
# Restoring model weights from best epoch 85 with val_accuracy: 0.5467

# %%
model.save("Proposed_Model.keras")

# %%
# Save history
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
model = load_model('Proposed_Model.keras')

# %%
# Load history
with open('training_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
epochs = range(1, len(history['loss']) + 1)

# Training and validation metrics
tr_loss = history['loss']
val_loss = history['val_loss']
tr_acc = history['accuracy']
val_acc = history['val_accuracy']
tr_precision = history['precision']
val_precision = history['val_precision']
tr_auc = history['auc']
val_auc = history['val_auc']

# %%
def print_best_metrics(metric_name, train, val):
    best_epoch = np.argmax(val) + 1
    print(f"📌 Best {metric_name} at epoch {best_epoch}:")
    print(f"   - Train {metric_name}: {abs(train[best_epoch - 1]):.4f}")
    print(f"   - Val {metric_name}:   {abs(val[best_epoch - 1]):.4f}\n")

print_best_metrics("Accuracy", tr_acc, val_acc)
print_best_metrics("Precision", tr_precision, val_precision)
print_best_metrics("AUC", tr_auc, val_auc)
print_best_metrics("Loss", [-x for x in tr_loss], [-x for x in val_loss])  # inverted for max-based search
# Out:
# 📌 Best Accuracy at epoch 85:
#    - Train Accuracy: 0.9354
#    - Val Accuracy:   0.5467
#
# 📌 Best Precision at epoch 79:
#    - Train Precision: 0.9466
#    - Val Precision:   0.8000
#
# 📌 Best AUC at epoch 67:
#    - Train AUC: 0.9807
#    - Val AUC:   0.7718
#
# 📌 Best Loss at epoch 85:
#    - Train Loss: 0.1505
#    - Val Loss:   0.6813

# %%
best_epoch_loss = np.argmin(val_loss)
best_val_loss = val_loss[best_epoch_loss]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_loss, color='red', label='Training Loss', linewidth=2)
plt.plot(epochs, val_loss, color='green', label='Validation Loss', linestyle='--', linewidth=2)
plt.scatter(best_epoch_loss + 1, best_val_loss, s=150, c='blue',
            label=f'Best epoch = {best_epoch_loss + 1}', edgecolors='black')
plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_acc = np.argmax(val_acc)
best_val_acc = val_acc[best_epoch_acc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_acc, color='red', label='Training Accuracy', linewidth=2)
plt.plot(epochs, val_acc, color='green', label='Validation Accuracy', linestyle='--', linewidth=2)
plt.scatter(best_epoch_acc + 1, best_val_acc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_acc + 1}', edgecolors='black')
plt.title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_prec = np.argmax(val_precision)
best_val_prec = val_precision[best_epoch_prec]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_precision, color='red', label='Training Precision', linewidth=2)
plt.plot(epochs, val_precision, color='green', label='Validation Precision', linestyle='--', linewidth=2)
plt.scatter(best_epoch_prec + 1, best_val_prec, s=150, c='blue',
            label=f'Best epoch = {best_epoch_prec + 1}', edgecolors='black')
plt.title('Training and Validation Precision', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_auc = np.argmax(val_auc)
best_val_auc = val_auc[best_epoch_auc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_auc, color='red', label='Training AUC', linewidth=2)
plt.plot(epochs, val_auc, color='green', label='Validation AUC', linestyle='--', linewidth=2)
plt.scatter(best_epoch_auc + 1, best_val_auc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_auc + 1}', edgecolors='black')
plt.title('Training and Validation AUC', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
# ==========================================
# Model Evaluation Function
# ==========================================
def evaluate_model(model, test_generator, labels, model_name, batch_size=32):
    """
    Evaluate a trained binary-classification model with dual inputs (image + handcrafted features).

    Args:
        model: Trained Keras model expecting ((img, hf), labels)
        test_generator: HandcraftedGeneratorWrapper instance
        labels: List of class names (e.g., ['Benign', 'Melanoma'])
        model_name: Name for display
        batch_size: Batch size (used for step calculation)

    Returns:
        metrics_dict: Dictionary with all metrics
        auc_curve_data: FPR, TPR for ROC curve plotting
    """

    steps = len(test_generator)

    y_true = []
    y_pred = []
    y_probs = []

    print(f"\n{'='*80}")
    print(f"Evaluating: {model_name}")
    print(f"{'='*80}")
    print(f"Total steps: {steps}")

    # Loop through test generator
    for step_idx in tqdm(range(steps), desc=f"Evaluating {model_name}", total=steps):
        # Get batch from generator
        images, labels_batch = test_generator[step_idx]

        # Predict using both inputs
        preds = model.predict(
            images,
            verbose=0
        )  # sigmoid outputs (probability of class 1)

        preds = preds.reshape(-1)

        y_probs.extend(preds)                      # probability for class 1
        y_pred.extend((preds >= 0.5).astype(int))  # binary classification using threshold 0.5

        # Labels from generator (binary)
        labels_batch = labels_batch.reshape(-1)
        y_true.extend(labels_batch.astype(int))

    # Convert to arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_probs = np.array(y_probs)

    print(f"\nTotal samples evaluated: {len(y_true)}")
    print(f"Class distribution: {np.bincount(y_true)}")

    # Metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    try:
        auc = roc_auc_score(y_true, y_probs)
    except ValueError:
        auc = float("nan")

    # Classification report
    report = classification_report(y_true, y_pred, target_names=labels, zero_division=0)

    # Print metrics
    print(f"\n{'='*80}")
    print(f"PERFORMANCE METRICS")
    print(f"{'='*80}")
    print(f"Accuracy  : {accuracy:.4f}")
    print(f"Precision : {precision:.4f}")
    print(f"Recall    : {recall:.4f}")
    print(f"F1 Score  : {f1:.4f}")
    print(f"AUC       : {auc:.4f}")
    print(f"{'='*80}\n")

    print("Classification Report:\n")
    print(report)

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Greens',
        linewidths=2,
        linecolor='black',
        xticklabels=labels,
        yticklabels=labels,
        annot_kws={"size": 16, "weight": "bold"},
        cbar_kws={"label": "Count"}
    )

    plt.title(f'Confusion Matrix: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_probs)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, 'b-', linewidth=3, label=f'AUC = {auc:.4f}')
    plt.plot([0, 1], [0, 1], 'k--', linewidth=2, label='Random Classifier')
    plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold')
    plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold')
    plt.title(f'ROC Curve: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.legend(fontsize=12, loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.tight_layout()
    plt.show()

    auc_curve_data = {"fpr": fpr, "tpr": tpr, "auc": auc}

    return {
        "model_name": model_name,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "auc": auc,
        "y_true": y_true,
        "y_pred": y_pred,
        "y_probs": y_probs,
        "confusion_matrix": cm
    }, auc_curve_data


# Evaluate
metrics, roc_data = evaluate_model(
    model=model,
    test_generator=test_data,
    labels=['Benign', 'Melanoma'],
    model_name='SkinCancerModel',
    batch_size=32
)

# Access results
print(f"\nTest Accuracy: {metrics['accuracy']:.4f}")
print(f"Test AUC: {metrics['auc']:.4f}")

# Plot ROC curve
fpr, tpr, auc = roc_data['fpr'], roc_data['tpr'], roc_data['auc']
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc:.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()
# Out:
# ================================================================================
# Evaluating: SkinCancerModel
# ================================================================================
# Total steps: 10
# Evaluating SkinCancerModel: 100%|██████████| 10/10 [00:10<00:00,  1.07s/it]
# Total samples evaluated: 300
# Class distribution: [150 150]
#
# ================================================================================
# PERFORMANCE METRICS
# ================================================================================
# Accuracy  : 0.5333
# Precision : 0.5191
# Recall    : 0.9067
# F1 Score  : 0.6602
# AUC       : 0.6718
# ================================================================================
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Benign       0.63      0.16      0.26       150
#     Melanoma       0.52      0.91      0.66       150
#
#     accuracy                           0.53       300
#    macro avg       0.58      0.53      0.46       300
# weighted avg       0.58      0.53      0.46       300
# Test Accuracy: 0.5333
# Test AUC: 0.6718

# %% [markdown]
# ----------------
# Bootstrap 95% Confidence interval

# %%
# -----------------------------
# Parameters
# -----------------------------
B = 1000                # number of bootstrap samples
RNG_SEED = 42

# 1) Get predictions and true labels
probs = model.predict(test_data, verbose=1).ravel()   # shape (N,) after ravel for binary
y_true = np.asarray(test_data.classes)                # shape (N,)
y_pred = (probs >= 0.5).astype(int)                   # thresholding for binary

# Point estimates
point_accuracy = accuracy_score(y_true, y_pred)
point_precision = precision_score(y_true, y_pred, average='binary', zero_division=0)
point_recall = recall_score(y_true, y_pred, average='binary', zero_division=0)
point_f1 = f1_score(y_true, y_pred, average='binary', zero_division=0)

# AUC for binary
try:
    point_auc = roc_auc_score(y_true, probs)
except Exception:
    point_auc = np.nan
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 487ms/step

# %%
# 2) Bootstrap
rng = np.random.RandomState(RNG_SEED)
metrics_boot = {k: [] for k in ["accuracy", "precision", "recall", "f1", "auc"]}
N = len(y_true)

for i in tqdm(range(B), desc="Bootstrap samples"):
    idx = rng.randint(0, N, size=N)   # sample with replacement
    y_true_b, y_pred_b, probs_b = y_true[idx], y_pred[idx], probs[idx]

    metrics_boot["accuracy"].append(accuracy_score(y_true_b, y_pred_b))
    metrics_boot["precision"].append(precision_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["recall"].append(recall_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["f1"].append(f1_score(y_true_b, y_pred_b, average='macro', zero_division=0))

    #probs_b = probs_b.ravel()   # ensure shape (N,)
    
    try:
        auc_b = roc_auc_score(y_true_b, probs_b)
    except Exception:
        auc_b = np.nan
    
    metrics_boot["auc"].append(auc_b)


# Convert lists to arrays
for k in metrics_boot:
    metrics_boot[k] = np.array(metrics_boot[k], dtype=np.float32)
# Out:
# Bootstrap samples: 100%|██████████| 1000/1000 [00:04<00:00, 248.29it/s]

# %%
# 3) Compute 95% CI
def ci95(arr):
    arr = arr[~np.isnan(arr)]
    if len(arr) == 0:
        return (np.nan, np.nan)
    return np.percentile(arr, [2.5, 97.5])

results = []
for name, point in [
    ("accuracy", point_accuracy),
    ("precision", point_precision),
    ("recall", point_recall),
    ("f1", point_f1),
    ("auc", point_auc)
]:
    lo, hi = ci95(metrics_boot[name])
    results.append({
        "metric": name,
        "point_estimate": point,
        "ci_lower": lo,
        "ci_upper": hi,
        "n_boot_valid": int(np.sum(~np.isnan(metrics_boot[name])))
    })

df_results = pd.DataFrame(results).set_index("metric")
pd.set_option("display.float_format", "{:.4f}".format)
print(df_results)
# Out:
#            point_estimate  ci_lower  ci_upper  n_boot_valid
# metric
# accuracy           0.5333    0.4799    0.5833          1000
# precision          0.5191    0.4879    0.6547          1000
# recall             0.9067    0.4953    0.5706          1000
# f1                 0.6602    0.4058    0.5098          1000
# auc                0.6718    0.6163    0.7275          1000

# %%
def plot_bootstrap_metrics(metrics_boot, df_results, n_cols=3, figsize_per_plot=(5, 4),
                           w_pad=0.6, h_pad=1.5, shift_factor=0.5):
    """
    Plot bootstrap metric distributions.

    Args:
        metrics_boot: dict of metric -> bootstrap array
        df_results: DataFrame with point estimates and CIs
        n_cols: 
            >0 -> number of columns for grid layout
             0 -> plot each metric separately (one figure per metric)
        figsize_per_plot: (width, height) per subplot
        w_pad: horizontal gap between subplots (grid mode only)
        h_pad: vertical gap between subplots (grid mode only)
        shift_factor: how much to center last row if not full (grid mode only)
    """

    metrics = list(metrics_boot.keys())
    n_metrics = len(metrics)

    # --------------------
    # Single-plot mode
    # --------------------
    if n_cols == 0:
        for metric in metrics:
            vals = metrics_boot[metric]
            vals_nonan = vals[~np.isnan(vals)]

            fig, ax = plt.subplots(figsize=figsize_per_plot)
            ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
            ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
            ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
            ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

            ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
            ax.legend()
            plt.tight_layout()
            plt.show()
        return  # done

    # --------------------
    # Grid mode
    # --------------------
    n_rows = int(np.ceil(n_metrics / n_cols))

    fig, axes = plt.subplots(n_rows, n_cols,
                             figsize=(figsize_per_plot[0]*n_cols,
                                      figsize_per_plot[1]*n_rows))
    axes = np.array(axes).reshape(-1)  # flatten

    for i, metric in enumerate(metrics):
        ax = axes[i]
        vals = metrics_boot[metric]
        vals_nonan = vals[~np.isnan(vals)]

        ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
        ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
        ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
        ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

        ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
        ax.legend()

        # 🔹 Format x-axis ticks to 2 decimal places
        ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:.2f}"))

    # remove unused axes
    for j in range(n_metrics, len(axes)):
        fig.delaxes(axes[j])

    # ---- Center last row if it's not full ----
    last_row_count = n_metrics % n_cols
    if last_row_count != 0:
        empty_slots = n_cols - last_row_count
        last_row_axes = axes[n_cols*(n_rows-1):n_cols*(n_rows-1)+last_row_count]

        for ax in last_row_axes:
            pos = ax.get_position()
            shift = (empty_slots / n_cols) * shift_factor
            pos_new = [pos.x0 + shift, pos.y0, pos.width, pos.height]
            ax.set_position(pos_new)

    plt.tight_layout(pad=1.0, w_pad=w_pad, h_pad=h_pad)
    plt.show()

# %%
plot_bootstrap_metrics(
    metrics_boot, 
    df_results, 
    n_cols=0,        # number of columns in grid (set 0 for separate plots, 2 or 3 for grid)
    w_pad=0.5,       # horizontal space between columns (increase -> wider gap)
    h_pad=1.0,       # vertical space between rows (increase -> taller gap)
    shift_factor=0.0 # how much to horizontally shift last-row plots for centering
)

# %% [markdown]
# --------------------
# Gradcam ++ (more advance visualization than previous version of mine)
