# %%
# === System & OS Utilities ===
import os
import math
import pickle
import sys
import warnings
import random
import logging
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.ERROR)

# === Progress Bar ===
from tqdm import tqdm

# === TensorFlow & Keras ===
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adamax, AdamW
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.layers import Layer
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import (Conv2D, 
                                     Dense,
                                     Dropout,
                                     Flatten,
                                     GlobalAveragePooling2D,
                                     GlobalMaxPooling2D,
                                     MaxPooling2D,
                                     BatchNormalization,
                                     ReLU,
                                     Add)
from tensorflow.keras.layers import (
    Layer, Conv2D, Dense, Dropout,
    GlobalAveragePooling2D, GlobalMaxPooling2D,
    Reshape, Multiply, Add, Activation, Concatenate
)
import os, numpy as np, cv2
from skimage.feature import local_binary_pattern
from tensorflow.keras import layers, Model, initializers
from tensorflow.keras.layers import Layer
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Data Handling ===
import numpy as np
import pandas as pd
import cv2

# === Visualization ===
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# === Scikit-learn ===
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, classification_report, confusion_matrix
)

# %%
print("Python version:", sys.version)
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("OpenCV version:", cv2.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Python version: 3.11.14 (main, Oct 21 2025, 18:27:30) [Clang 20.1.8 ]
# TensorFlow version: 2.16.2
# Keras version: 3.5.0
# NumPy version: 1.26.4
# Pandas version: 2.2.3
# OpenCV version: 4.6.0
# Matplotlib version: 3.7.5
# Seaborn version: 0.12.2
# Scikit-learn version: 1.2.2

# %%
#python version 3.11.11
#!python -m pip install tensorflow==2.18.0 keras==3.5.0 numpy==1.26.4 pandas==2.2.3 opencv-python==4.6.0.66 matplotlib==3.7.5 seaborn==0.12.2 scikit-learn==1.2.2

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPUs detected: {len(gpus)}")
    except RuntimeError as e:
        print(f"Error setting GPU memory growth: {e}")
else:
    print("No GPUs detected.")
# Out:
# GPUs detected: 1

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
EPOCH = 100
img_shape=(*IMG_SIZE,3)
dataset_path = r"/kaggle/input/preprocessed-augmented-breakhis-dataset/preprocessed_breakhis_dataset/tissue_only_normalized"
labels = ['Benign', 'Malignant']
print("Class Names:", labels)
# Out:
# Class Names: ['Benign', 'Malignant']

# %%
def data_frame(root_path, target_folder):

    class_paths = []
    classes = []
    patient_ids = []

    for label in os.listdir(root_path):

        class_dir = os.path.join(root_path, label)
        if not os.path.isdir(class_dir):
            continue

        target_dir = os.path.join(class_dir, target_folder)

        if not os.path.isdir(target_dir):
            print(f"[WARNING] '{target_folder}' not found in class '{label}'. Skipping.")
            continue

        for image in os.listdir(target_dir):

            if not image.lower().endswith(('.png','.jpg','.jpeg')):
                continue

            path = os.path.join(target_dir,image)

            parts = image.split('-')

            # Skip malformed filenames
            if len(parts) < 3:
                print(f"Skipping malformed filename: {image}")
                continue

            patient_id = parts[1] + "-" + parts[2]

            class_paths.append(path)
            classes.append(label)
            patient_ids.append(patient_id)

    df = pd.DataFrame({
        'Class Path': class_paths,
        'Class': classes,
        'PatientID': patient_ids
    })

    return df

# %%
main_frame = data_frame(
    root_path=dataset_path,
    target_folder="400X"   # "40X", "100X", "200X", "400X"
)

patients = main_frame['PatientID'].unique()

train_pat, temp_pat = train_test_split(
    patients,
    test_size=0.20,
    random_state=42
)

val_pat, test_pat = train_test_split(
    temp_pat,
    test_size=0.5,
    random_state=42
)

train_dataframe = main_frame[main_frame['PatientID'].isin(train_pat)]
validation_dataframe = main_frame[main_frame['PatientID'].isin(val_pat)]
test_dataframe = main_frame[main_frame['PatientID'].isin(test_pat)]


print("Train patients:",len(set(train_dataframe.PatientID)))
print("Val patients:",len(set(validation_dataframe.PatientID)))
print("Test patients:",len(set(test_dataframe.PatientID)))

print("Overlap train-val:",set(train_dataframe.PatientID) & set(validation_dataframe.PatientID))
print("Overlap train-test:",set(train_dataframe.PatientID) & set(test_dataframe.PatientID))
print("Overlap val-test:",set(validation_dataframe.PatientID) & set(test_dataframe.PatientID))
print()
train_counts = train_dataframe['Class'].value_counts()
val_counts = validation_dataframe['Class'].value_counts()
test_counts = test_dataframe['Class'].value_counts()

count_table = pd.DataFrame({
    "Train": train_counts,
    "Validation": val_counts,
    "Test": test_counts
}).fillna(0).astype(int)

count_table["Total"] = count_table.sum(axis=1)
grand_total = pd.DataFrame({
    "Train": [count_table["Train"].sum()],
    "Validation": [count_table["Validation"].sum()],
    "Test": [count_table["Test"].sum()],
    "Total": [count_table["Total"].sum()]
}, index=["Total"])
count_table = pd.concat([count_table, grand_total])

print(count_table)

BATCH_SIZE = min(BATCH_SIZE, len(validation_dataframe))
print(f"Batch Size = {BATCH_SIZE}")
# Out:
# Train patients: 64
# Val patients: 8
# Test patients: 9
# Overlap train-val: set()
# Overlap train-test: set()
# Overlap val-test: set()
#
#            Train  Validation  Test  Total
# Benign      1252         186    62   1500
# Malignant   1134         142   224   1500
# Total       2386         328   286   3000
# Batch Size = 32

# %%
# Combine and sum the counts
total_counts = train_counts.add(val_counts, fill_value=0)
total_counts = total_counts.add(test_counts, fill_value=0)
total_counts = total_counts.sort_index()

# Prepare labels with percentages
total = total_counts.sum()
labels_with_percent = [f"{label} ({(count/total)*100:.1f}%)" for label, count in zip(total_counts.index, total_counts.values)]

# Define custom autopct function to show raw count
def make_autopct(values):
    def autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f"{count}"
    return autopct

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_counts.values, labels=labels_with_percent, autopct=make_autopct(total_counts.values), startangle=140, textprops={'fontsize': 12})
plt.axis('equal')
plt.show()

# %%
# Count occurrences of each class in train, validation, and test datasets
train_counts = train_dataframe['Class'].value_counts().sort_index()
val_counts = validation_dataframe['Class'].value_counts().sort_index()
test_counts = test_dataframe['Class'].value_counts().sort_index()

# Combine into a DataFrame with the index kept as a column
data_counts = pd.DataFrame({
    'Class': train_counts.index,
    'Train': train_counts.values,
    'Validation': val_counts.values,
    'Test': test_counts.values
}).melt(id_vars='Class', var_name='Dataset', value_name='Count')

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(y='Class', x='Count', hue='Dataset', data=data_counts, 
                 palette=['blue', 'orange', 'green'], orient='h', width=0.6)

# Add count labels to the right of the bars with slight downward offset
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', 
                (p.get_width(), p.get_y() + p.get_height() / 2.0 + 0.05),  # pushed slightly down
                ha='left', va='center', 
                fontsize=10, color='black', 
                xytext=(5, 0), textcoords='offset points')

# Remove borders (spines)
sns.despine(top=True, right=True, left=False, bottom=False)

# Dynamically set the x-axis limits with some extra space on the right
left, right = ax.get_xlim()  # Get current x-limits

# Set the new right limit with a 15% increase
right += (right - left) * 0.15  # Increase right by 15%

# Apply the new limits to the x-axis
ax.set_xlim(left, right)

# Add labels and title
plt.ylabel("Class")
plt.xlabel("Count")
plt.title("Class Distribution in Train, Validation, and Test Sets")

# Move the legend
plt.legend(title="Dataset", loc='upper right', fontsize=8)

# Add grid only along x-axis
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Tidy layout
plt.tight_layout()
plt.show()

# %%
def preprocess_image(image):

    image = image.astype(np.float32)

    min_val = image.min()
    max_val = image.max()

    # avoid division by zero
    if max_val - min_val < 1e-6:
        return np.zeros_like(image, dtype=np.float32)

    # min-max scale to [0, 1]
    image = (image - min_val) / (max_val - min_val)
    
    return image

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,

    # ---- Geometric ----
    rotation_range=30,         
    zoom_range=0.1,           
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,

    horizontal_flip=True,
    vertical_flip=True,

    fill_mode="reflect"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)


train_data = train_datagen.flow_from_dataframe(train_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', seed=42)

validation_data = val_datagen.flow_from_dataframe(validation_dataframe, x_col='Class Path',
                                     y_col='Class', batch_size=BATCH_SIZE,
                                     target_size=IMG_SIZE, class_mode='binary', seed=42)

test_data = test_datagen.flow_from_dataframe(test_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', shuffle=False, seed=42)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.

# %%
class RestoreBestValidationModel(Callback):
    """
    Custom Keras Callback to restore model weights from the best epoch based on validation accuracy.
    - Tracks the best validation accuracy during training.
    - Restores the model weights from the epoch with the best validation accuracy when training finishes.
    """
    
    def __init__(self):
        super(RestoreBestValidationModel, self).__init__()
        # Initialize best validation accuracy, epoch, and weights to track the best model
        self.best_val_acc = -1
        self.best_epoch = -1
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        """
        Callback function executed at the end of each epoch.
        - Compares the current validation accuracy with the best validation accuracy.
        - If the current validation accuracy is higher or tied but at a later epoch, updates the best model weights.
        """
        # Get validation accuracy from logs
        val_acc = logs.get('val_accuracy')
        
        if val_acc is not None:
            # Update the best validation accuracy and weights if the current one is better or at a later epoch
            if val_acc > self.best_val_acc or (val_acc == self.best_val_acc and epoch > self.best_epoch):
                self.best_val_acc = val_acc
                self.best_epoch = epoch
                self.best_weights = self.model.get_weights()  # Store the model's weights
                print(f"\nModel weights updated at epoch {epoch + 1} with val_accuracy: {val_acc:.4f}")

    def on_train_end(self, logs=None):
        """
        Callback function executed at the end of training.
        - Restores the model weights from the epoch with the best validation accuracy.
        """
        # If we found a better model during training, restore the best weights
        if self.best_weights is not None:
            print(f"Restoring model weights from best epoch {self.best_epoch + 1} with val_accuracy: {self.best_val_acc:.4f}")
            self.model.set_weights(self.best_weights)  # Set the weights back to the best model's weights

# Instantiate the callback
restore_best = RestoreBestValidationModel()

# %%
base_model = tf.keras.applications.EfficientNetV2B0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights=None
)

x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)  # optional hidden layer....
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)  
model = tf.keras.Model(inputs=base_model.input, outputs=output)
# Out:
# I0000 00:00:1772988636.381706      21 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# ===============================
# Dynamic Cosine Decay
# ===============================
num_train_samples = sum(list(train_counts))

steps_per_epoch = math.ceil(num_train_samples / BATCH_SIZE)
decay_steps = steps_per_epoch * EPOCH

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4,
    decay_steps=decay_steps,
    alpha=1e-3   
)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=5e-5,   
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-7
)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=[
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

print("Model compiled with optimized AdamW + CosineDecay")
print(f"Train samples: {num_train_samples}")
print(f"Steps per epoch: {steps_per_epoch}")
print(f"Total decay steps: {decay_steps}")
# Out:
# Model compiled with optimized AdamW + CosineDecay
# Train samples: 2400
# Steps per epoch: 75
# Total decay steps: 7500

# %%
all_steps = np.arange(decay_steps)
lrs = [lr_schedule(step).numpy() for step in all_steps]

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(8,4))
plt.plot(all_steps, lrs)
plt.title("Cosine Decay Learning Rate Schedule")
plt.xlabel("Training Steps")
plt.ylabel("Learning Rate")
plt.grid(True)
plt.show()

# %%
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=EPOCH,
    callbacks=[restore_best],
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772988699.851788      61 service.cc:148] XLA service 0x7b5c780054c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772988699.853378      61 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772988707.041540      61 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1772988717.231986      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772988717.416104      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772988717.875755      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1772988718.081653      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  1/75 ━━━━━━━━━━━━━━━━━━━━ 1:44:19 85s/step - accuracy: 0.5312 - auc: 0.5312 - loss: 0.6856 - precision: 0.3846 - recall: 0.4167
# I0000 00:00:1772988738.546643      61 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.5383 - auc: 0.5476 - loss: 0.6999 - precision: 0.5403 - recall: 0.4526
# Model weights updated at epoch 1 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 130s 612ms/step - accuracy: 0.5384 - auc: 0.5479 - loss: 0.6998 - precision: 0.5404 - recall: 0.4530 - val_accuracy: 0.5000 - val_auc: 0.5912 - val_loss: 0.9554 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.7001 - auc: 0.7703 - loss: 0.5725 - precision: 0.7320 - recall: 0.6361
# Model weights updated at epoch 2 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.7004 - auc: 0.7707 - loss: 0.5721 - precision: 0.7322 - recall: 0.6369 - val_accuracy: 0.5000 - val_auc: 0.1789 - val_loss: 1.6354 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7524 - auc: 0.8238 - loss: 0.5180 - precision: 0.7355 - recall: 0.7937
# Model weights updated at epoch 3 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.7525 - auc: 0.8240 - loss: 0.5178 - precision: 0.7356 - recall: 0.7936 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 897.9325 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 377ms/step - accuracy: 0.7566 - auc: 0.8354 - loss: 0.5082 - precision: 0.7333 - recall: 0.8271 - val_accuracy: 0.4967 - val_auc: 0.4967 - val_loss: 99.1492 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.7922 - auc: 0.8665 - loss: 0.4565 - precision: 0.7588 - recall: 0.8363
# Model weights updated at epoch 5 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.7919 - auc: 0.8662 - loss: 0.4569 - precision: 0.7585 - recall: 0.8363 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 97.8763 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.7603 - auc: 0.8379 - loss: 0.4983 - precision: 0.7467 - recall: 0.7987 - val_accuracy: 0.4967 - val_auc: 0.4967 - val_loss: 70.0576 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.7694 - auc: 0.8473 - loss: 0.4850 - precision: 0.7415 - recall: 0.8319
# Model weights updated at epoch 7 with val_accuracy: 0.7567
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.7693 - auc: 0.8472 - loss: 0.4851 - precision: 0.7414 - recall: 0.8319 - val_accuracy: 0.7567 - val_auc: 0.8572 - val_loss: 0.6550 - val_precision: 0.8130 - val_recall: 0.6667
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.7814 - auc: 0.8472 - loss: 0.4817 - precision: 0.7413 - recall: 0.8721 - val_accuracy: 0.5067 - val_auc: 0.5123 - val_loss: 12.1107 - val_precision: 0.5041 - val_recall: 0.8267
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.7730 - auc: 0.8498 - loss: 0.4811 - precision: 0.7325 - recall: 0.8315 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 38.7771 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.7867 - auc: 0.8536 - loss: 0.4697 - precision: 0.7506 - recall: 0.8731 - val_accuracy: 0.5000 - val_auc: 0.5067 - val_loss: 14.5398 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.7771 - auc: 0.8554 - loss: 0.4701 - precision: 0.7449 - recall: 0.8383 - val_accuracy: 0.5533 - val_auc: 0.5897 - val_loss: 5.0781 - val_precision: 0.7222 - val_recall: 0.1733
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.7672 - auc: 0.8432 - loss: 0.4798 - precision: 0.7182 - recall: 0.8642 - val_accuracy: 0.4833 - val_auc: 0.4830 - val_loss: 102.3368 - val_precision: 0.4912 - val_recall: 0.9333
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 395ms/step - accuracy: 0.7658 - auc: 0.8469 - loss: 0.4768 - precision: 0.7282 - recall: 0.8502 - val_accuracy: 0.5033 - val_auc: 0.5033 - val_loss: 157.7775 - val_precision: 0.5017 - val_recall: 0.9800
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.7670 - auc: 0.8404 - loss: 0.4911 - precision: 0.7355 - recall: 0.8416 - val_accuracy: 0.4967 - val_auc: 0.5610 - val_loss: 3.1628 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.7674 - auc: 0.8408 - loss: 0.4919 - precision: 0.7288 - recall: 0.8434 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 67.1803 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.7728 - auc: 0.8465 - loss: 0.4790 - precision: 0.7423 - recall: 0.8373 - val_accuracy: 0.4767 - val_auc: 0.4633 - val_loss: 22.1942 - val_precision: 0.4881 - val_recall: 0.9533
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.7618 - auc: 0.8416 - loss: 0.4921 - precision: 0.7217 - recall: 0.8475 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 6.4505 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.7708 - auc: 0.8507 - loss: 0.4769 - precision: 0.7418 - recall: 0.8377 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 36.0661 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.7734 - auc: 0.8488 - loss: 0.4715 - precision: 0.7460 - recall: 0.8448 - val_accuracy: 0.5000 - val_auc: 0.1558 - val_loss: 2.1047 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.7752 - auc: 0.8467 - loss: 0.4818 - precision: 0.7382 - recall: 0.8330 - val_accuracy: 0.5000 - val_auc: 0.4833 - val_loss: 10.7151 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.7618 - auc: 0.8433 - loss: 0.4783 - precision: 0.7192 - recall: 0.8720 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 65.5405 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.7807 - auc: 0.8581 - loss: 0.4719 - precision: 0.7289 - recall: 0.8903 - val_accuracy: 0.5167 - val_auc: 0.2774 - val_loss: 1.5894 - val_precision: 0.6667 - val_recall: 0.0667
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.7900 - auc: 0.8636 - loss: 0.4574 - precision: 0.7464 - recall: 0.8828 - val_accuracy: 0.5000 - val_auc: 0.5034 - val_loss: 51.1138 - val_precision: 0.5000 - val_recall: 0.9733
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 390ms/step - accuracy: 0.7657 - auc: 0.8477 - loss: 0.4749 - precision: 0.7112 - recall: 0.8803 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 28.0694 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 394ms/step - accuracy: 0.7723 - auc: 0.8422 - loss: 0.4904 - precision: 0.7267 - recall: 0.8578 - val_accuracy: 0.7133 - val_auc: 0.8551 - val_loss: 0.6372 - val_precision: 0.7963 - val_recall: 0.5733
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - accuracy: 0.7780 - auc: 0.8548 - loss: 0.4615 - precision: 0.7312 - recall: 0.8837 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 19.4638 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.7959 - auc: 0.8691 - loss: 0.4460 - precision: 0.7628 - recall: 0.8674 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 14.2202 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.7837 - auc: 0.8689 - loss: 0.4462 - precision: 0.7326 - recall: 0.8673 - val_accuracy: 0.5000 - val_auc: 0.4967 - val_loss: 8.6004 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.7686 - auc: 0.8587 - loss: 0.4625 - precision: 0.7130 - recall: 0.8709 - val_accuracy: 0.5000 - val_auc: 0.7609 - val_loss: 3.5842 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.7766 - auc: 0.8642 - loss: 0.4552 - precision: 0.7343 - recall: 0.8666 - val_accuracy: 0.5000 - val_auc: 0.5301 - val_loss: 8.8566 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.7828 - auc: 0.8544 - loss: 0.4672 - precision: 0.7324 - recall: 0.8887 - val_accuracy: 0.4800 - val_auc: 0.3742 - val_loss: 5.6188 - val_precision: 0.4898 - val_recall: 0.9600
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.7681 - auc: 0.8445 - loss: 0.4842 - precision: 0.7232 - recall: 0.8451 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 15.3146 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 387ms/step - accuracy: 0.8048 - auc: 0.8791 - loss: 0.4301 - precision: 0.7714 - recall: 0.8824 - val_accuracy: 0.4933 - val_auc: 0.5430 - val_loss: 0.8960 - val_precision: 0.4955 - val_recall: 0.7400
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.7989 - auc: 0.8811 - loss: 0.4283 - precision: 0.7574 - recall: 0.8717 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 57.7041 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.7939 - auc: 0.8805 - loss: 0.4302 - precision: 0.7773 - recall: 0.8226 - val_accuracy: 0.5000 - val_auc: 0.5857 - val_loss: 2.4728 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 397ms/step - accuracy: 0.7968 - auc: 0.8768 - loss: 0.4422 - precision: 0.7748 - recall: 0.8359 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 45.7766 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.7958 - auc: 0.8908 - loss: 0.4143 - precision: 0.7674 - recall: 0.8672 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 22.4243 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 390ms/step - accuracy: 0.8163 - auc: 0.8966 - loss: 0.4048 - precision: 0.8033 - recall: 0.8346 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 624.2567 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - accuracy: 0.7828 - auc: 0.8668 - loss: 0.4615 - precision: 0.7555 - recall: 0.8378 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 50.8981 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8152 - auc: 0.9030 - loss: 0.3919 - precision: 0.8114 - recall: 0.8281 - val_accuracy: 0.4967 - val_auc: 0.5000 - val_loss: 30.3790 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - accuracy: 0.8117 - auc: 0.8986 - loss: 0.3979 - precision: 0.8022 - recall: 0.8278 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 136.9817 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8256 - auc: 0.9160 - loss: 0.3713 - precision: 0.8130 - recall: 0.8527
# Model weights updated at epoch 42 with val_accuracy: 0.7600
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8256 - auc: 0.9158 - loss: 0.3715 - precision: 0.8130 - recall: 0.8525 - val_accuracy: 0.7600 - val_auc: 0.8577 - val_loss: 0.7844 - val_precision: 0.8145 - val_recall: 0.6733
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 379ms/step - accuracy: 0.8274 - auc: 0.9156 - loss: 0.3679 - precision: 0.8087 - recall: 0.8563 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 7.7657 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8213 - auc: 0.9027 - loss: 0.3933 - precision: 0.8019 - recall: 0.8485 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 73.1437 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.8189 - auc: 0.9051 - loss: 0.3856 - precision: 0.8096 - recall: 0.8257 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 121.2977 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.8255 - auc: 0.9099 - loss: 0.3813 - precision: 0.8395 - recall: 0.7969 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 520.0054 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8161 - auc: 0.9099 - loss: 0.3785 - precision: 0.8325 - recall: 0.7952 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 24.6025 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.8303 - auc: 0.9200 - loss: 0.3596 - precision: 0.8302 - recall: 0.8288 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 127.1394 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 379ms/step - accuracy: 0.8353 - auc: 0.9199 - loss: 0.3615 - precision: 0.8513 - recall: 0.8112 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 45.7948 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.8402 - auc: 0.9268 - loss: 0.3395 - precision: 0.8522 - recall: 0.8206 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 26.8618 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - accuracy: 0.8480 - auc: 0.9272 - loss: 0.3435 - precision: 0.8614 - recall: 0.8332 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 12.3061 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.8440 - auc: 0.9279 - loss: 0.3394 - precision: 0.8714 - recall: 0.8105 - val_accuracy: 0.5000 - val_auc: 0.3638 - val_loss: 3.6658 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.8387 - auc: 0.9291 - loss: 0.3366 - precision: 0.8458 - recall: 0.8263 - val_accuracy: 0.7400 - val_auc: 0.7849 - val_loss: 1.0178 - val_precision: 0.7571 - val_recall: 0.7067
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 379ms/step - accuracy: 0.8469 - auc: 0.9260 - loss: 0.3418 - precision: 0.8687 - recall: 0.8174 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 93.1569 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.8467 - auc: 0.9279 - loss: 0.3398 - precision: 0.8583 - recall: 0.8228 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 184.7855 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8576 - auc: 0.9262 - loss: 0.3434 - precision: 0.8714 - recall: 0.8395 - val_accuracy: 0.4967 - val_auc: 0.4967 - val_loss: 19.5909 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.8592 - auc: 0.9385 - loss: 0.3135 - precision: 0.8949 - recall: 0.8182 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 137.9635 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.8547 - auc: 0.9392 - loss: 0.3115 - precision: 0.8698 - recall: 0.8369 - val_accuracy: 0.5000 - val_auc: 0.4900 - val_loss: 37.5528 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8348 - auc: 0.9212 - loss: 0.3529 - precision: 0.8813 - recall: 0.7699 - val_accuracy: 0.6667 - val_auc: 0.7286 - val_loss: 1.5519 - val_precision: 0.7976 - val_recall: 0.4467
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 396ms/step - accuracy: 0.8498 - auc: 0.9346 - loss: 0.3247 - precision: 0.8607 - recall: 0.8313 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 104.4837 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.8524 - auc: 0.9382 - loss: 0.3150 - precision: 0.8716 - recall: 0.8290 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 134.8003 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - accuracy: 0.8563 - auc: 0.9379 - loss: 0.3135 - precision: 0.8820 - recall: 0.8297 - val_accuracy: 0.6333 - val_auc: 0.7821 - val_loss: 2.0821 - val_precision: 0.8571 - val_recall: 0.3200
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.8542 - auc: 0.9394 - loss: 0.3107 - precision: 0.8758 - recall: 0.8300 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 50.2973 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 379ms/step - accuracy: 0.8499 - auc: 0.9318 - loss: 0.3315 - precision: 0.8581 - recall: 0.8300 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 9.3334 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 390ms/step - accuracy: 0.8577 - auc: 0.9396 - loss: 0.3111 - precision: 0.8901 - recall: 0.8234 - val_accuracy: 0.4933 - val_auc: 0.3435 - val_loss: 5.5655 - val_precision: 0.4966 - val_recall: 0.9867
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8652 - auc: 0.9435 - loss: 0.3023 - precision: 0.8932 - recall: 0.8235 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 27.3474 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 388ms/step - accuracy: 0.8563 - auc: 0.9373 - loss: 0.3199 - precision: 0.8585 - recall: 0.8450 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 100.3253 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.8643 - auc: 0.9450 - loss: 0.2955 - precision: 0.8752 - recall: 0.8381 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 69.0696 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 387ms/step - accuracy: 0.8607 - auc: 0.9408 - loss: 0.3136 - precision: 0.8621 - recall: 0.8521 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 5.1262 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.8617 - auc: 0.9455 - loss: 0.2951 - precision: 0.8791 - recall: 0.8396 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 114.3497 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.8800 - auc: 0.9474 - loss: 0.2866 - precision: 0.9034 - recall: 0.8480 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 65.8404 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.8602 - auc: 0.9411 - loss: 0.3021 - precision: 0.8789 - recall: 0.8306 - val_accuracy: 0.4967 - val_auc: 0.4967 - val_loss: 45.1528 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8804 - auc: 0.9559 - loss: 0.2684 - precision: 0.8767 - recall: 0.8788 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 133.5225 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8725 - auc: 0.9483 - loss: 0.2883 - precision: 0.8943 - recall: 0.8458 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 57.2258 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 380ms/step - accuracy: 0.8814 - auc: 0.9522 - loss: 0.2732 - precision: 0.9113 - recall: 0.8440 - val_accuracy: 0.5067 - val_auc: 0.5185 - val_loss: 3.3713 - val_precision: 0.5034 - val_recall: 0.9800
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8619 - auc: 0.9491 - loss: 0.2858 - precision: 0.8792 - recall: 0.8368 - val_accuracy: 0.4900 - val_auc: 0.5440 - val_loss: 3.0388 - val_precision: 0.4949 - val_recall: 0.9800
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 379ms/step - accuracy: 0.8706 - auc: 0.9493 - loss: 0.2883 - precision: 0.8993 - recall: 0.8377 - val_accuracy: 0.4167 - val_auc: 0.3945 - val_loss: 6.1278 - val_precision: 0.4269 - val_recall: 0.4867
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 390ms/step - accuracy: 0.8786 - auc: 0.9478 - loss: 0.2878 - precision: 0.8981 - recall: 0.8564 - val_accuracy: 0.4833 - val_auc: 0.4777 - val_loss: 3.4694 - val_precision: 0.4779 - val_recall: 0.3600
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.8704 - auc: 0.9534 - loss: 0.2709 - precision: 0.8986 - recall: 0.8348 - val_accuracy: 0.4400 - val_auc: 0.2722 - val_loss: 2.6979 - val_precision: 0.4679 - val_recall: 0.8733
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8669 - auc: 0.9429 - loss: 0.2998 - precision: 0.9011 - recall: 0.8246 - val_accuracy: 0.7000 - val_auc: 0.7968 - val_loss: 1.3873 - val_precision: 0.6562 - val_recall: 0.8400
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8762 - auc: 0.9519 - loss: 0.2764 - precision: 0.8930 - recall: 0.8558 - val_accuracy: 0.4567 - val_auc: 0.3481 - val_loss: 5.5262 - val_precision: 0.4774 - val_recall: 0.9133
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 381ms/step - accuracy: 0.8714 - auc: 0.9519 - loss: 0.2782 - precision: 0.8790 - recall: 0.8604 - val_accuracy: 0.5000 - val_auc: 0.4900 - val_loss: 7.1940 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8769 - auc: 0.9522 - loss: 0.2787 - precision: 0.9084 - recall: 0.8365 - val_accuracy: 0.4967 - val_auc: 0.4900 - val_loss: 26.9598 - val_precision: 0.4983 - val_recall: 0.9933
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8792 - auc: 0.9517 - loss: 0.2814 - precision: 0.9094 - recall: 0.8485 - val_accuracy: 0.4300 - val_auc: 0.2986 - val_loss: 2.6523 - val_precision: 0.4618 - val_recall: 0.8467
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8783 - auc: 0.9564 - loss: 0.2644 - precision: 0.8844 - recall: 0.8652 - val_accuracy: 0.7100 - val_auc: 0.8234 - val_loss: 0.7280 - val_precision: 0.7368 - val_recall: 0.6533
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 392ms/step - accuracy: 0.8672 - auc: 0.9469 - loss: 0.2897 - precision: 0.8924 - recall: 0.8424 - val_accuracy: 0.7033 - val_auc: 0.7659 - val_loss: 0.8549 - val_precision: 0.6704 - val_recall: 0.8000
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8747 - auc: 0.9524 - loss: 0.2754 - precision: 0.8981 - recall: 0.8453 - val_accuracy: 0.7467 - val_auc: 0.8130 - val_loss: 1.3243 - val_precision: 0.7500 - val_recall: 0.7400
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8681 - auc: 0.9527 - loss: 0.2722 - precision: 0.8931 - recall: 0.8422 - val_accuracy: 0.4967 - val_auc: 0.4999 - val_loss: 3.6342 - val_precision: 0.4983 - val_recall: 0.9733
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 391ms/step - accuracy: 0.8756 - auc: 0.9574 - loss: 0.2602 - precision: 0.8898 - recall: 0.8517 - val_accuracy: 0.5033 - val_auc: 0.5081 - val_loss: 3.8804 - val_precision: 0.5017 - val_recall: 0.9933
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8689 - auc: 0.9534 - loss: 0.2690 - precision: 0.8863 - recall: 0.8455 - val_accuracy: 0.6667 - val_auc: 0.7240 - val_loss: 1.0152 - val_precision: 0.6202 - val_recall: 0.8600
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8817 - auc: 0.9556 - loss: 0.2670 - precision: 0.8985 - recall: 0.8518
# Model weights updated at epoch 91 with val_accuracy: 0.8800
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 393ms/step - accuracy: 0.8818 - auc: 0.9556 - loss: 0.2670 - precision: 0.8986 - recall: 0.8518 - val_accuracy: 0.8800 - val_auc: 0.9646 - val_loss: 0.2600 - val_precision: 0.8562 - val_recall: 0.9133
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 391ms/step - accuracy: 0.8804 - auc: 0.9563 - loss: 0.2645 - precision: 0.9087 - recall: 0.8512 - val_accuracy: 0.8367 - val_auc: 0.9252 - val_loss: 0.4847 - val_precision: 0.9174 - val_recall: 0.7400
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 387ms/step - accuracy: 0.8927 - auc: 0.9599 - loss: 0.2534 - precision: 0.9150 - recall: 0.8709 - val_accuracy: 0.8700 - val_auc: 0.9525 - val_loss: 0.3229 - val_precision: 0.8491 - val_recall: 0.9000
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 385ms/step - accuracy: 0.8811 - auc: 0.9540 - loss: 0.2739 - precision: 0.9049 - recall: 0.8534 - val_accuracy: 0.8700 - val_auc: 0.9593 - val_loss: 0.2948 - val_precision: 0.8364 - val_recall: 0.9200
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 382ms/step - accuracy: 0.8999 - auc: 0.9630 - loss: 0.2441 - precision: 0.9160 - recall: 0.8757 - val_accuracy: 0.8533 - val_auc: 0.9658 - val_loss: 0.3020 - val_precision: 0.7978 - val_recall: 0.9467
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.8741 - auc: 0.9574 - loss: 0.2623 - precision: 0.8937 - recall: 0.8493
# Model weights updated at epoch 96 with val_accuracy: 0.8967
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 383ms/step - accuracy: 0.8741 - auc: 0.9574 - loss: 0.2625 - precision: 0.8937 - recall: 0.8493 - val_accuracy: 0.8967 - val_auc: 0.9647 - val_loss: 0.2304 - val_precision: 0.9161 - val_recall: 0.8733
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 393ms/step - accuracy: 0.8797 - auc: 0.9530 - loss: 0.2712 - precision: 0.9043 - recall: 0.8514 - val_accuracy: 0.8933 - val_auc: 0.9583 - val_loss: 0.2526 - val_precision: 0.9155 - val_recall: 0.8667
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 389ms/step - accuracy: 0.8833 - auc: 0.9561 - loss: 0.2625 - precision: 0.9064 - recall: 0.8539 - val_accuracy: 0.8933 - val_auc: 0.9594 - val_loss: 0.2477 - val_precision: 0.9155 - val_recall: 0.8667
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 387ms/step - accuracy: 0.8917 - auc: 0.9632 - loss: 0.2475 - precision: 0.9055 - recall: 0.8712 - val_accuracy: 0.8900 - val_auc: 0.9654 - val_loss: 0.2344 - val_precision: 0.8824 - val_recall: 0.9000
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 386ms/step - accuracy: 0.8864 - auc: 0.9600 - loss: 0.2551 - precision: 0.9156 - recall: 0.8534 - val_accuracy: 0.8933 - val_auc: 0.9671 - val_loss: 0.2316 - val_precision: 0.8831 - val_recall: 0.9067
# Restoring model weights from best epoch 96 with val_accuracy: 0.8967

# %%
model.save("Proposed_Model.keras")

# %%
# Save history
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
model = load_model('Proposed_Model.keras')

# %%
# Load history
with open('training_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
epochs = range(1, len(history['loss']) + 1)

# Training and validation metrics
tr_loss = history['loss']
val_loss = history['val_loss']
tr_acc = history['accuracy']
val_acc = history['val_accuracy']
tr_precision = history['precision']
val_precision = history['val_precision']
tr_auc = history['auc']
val_auc = history['val_auc']

# %%
def print_best_metrics(metric_name, train, val):
    best_epoch = np.argmax(val) + 1
    print(f"📌 Best {metric_name} at epoch {best_epoch}:")
    print(f"   - Train {metric_name}: {abs(train[best_epoch - 1]):.4f}")
    print(f"   - Val {metric_name}:   {abs(val[best_epoch - 1]):.4f}\n")

print_best_metrics("Accuracy", tr_acc, val_acc)
print_best_metrics("Precision", tr_precision, val_precision)
print_best_metrics("AUC", tr_auc, val_auc)
print_best_metrics("Loss", [-x for x in tr_loss], [-x for x in val_loss])  # inverted for max-based search
# Out:
# 📌 Best Accuracy at epoch 96:
#    - Train Accuracy: 0.8746
#    - Val Accuracy:   0.8967
#
# 📌 Best Precision at epoch 92:
#    - Train Precision: 0.9040
#    - Val Precision:   0.9174
#
# 📌 Best AUC at epoch 100:
#    - Train AUC: 0.9530
#    - Val AUC:   0.9671
#
# 📌 Best Loss at epoch 96:
#    - Train Loss: 0.2758
#    - Val Loss:   0.2304

# %%
best_epoch_loss = np.argmin(val_loss)
best_val_loss = val_loss[best_epoch_loss]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_loss, color='red', label='Training Loss', linewidth=2)
plt.plot(epochs, val_loss, color='green', label='Validation Loss', linestyle='--', linewidth=2)
plt.scatter(best_epoch_loss + 1, best_val_loss, s=150, c='blue',
            label=f'Best epoch = {best_epoch_loss + 1}', edgecolors='black')
plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_acc = np.argmax(val_acc)
best_val_acc = val_acc[best_epoch_acc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_acc, color='red', label='Training Accuracy', linewidth=2)
plt.plot(epochs, val_acc, color='green', label='Validation Accuracy', linestyle='--', linewidth=2)
plt.scatter(best_epoch_acc + 1, best_val_acc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_acc + 1}', edgecolors='black')
plt.title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_prec = np.argmax(val_precision)
best_val_prec = val_precision[best_epoch_prec]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_precision, color='red', label='Training Precision', linewidth=2)
plt.plot(epochs, val_precision, color='green', label='Validation Precision', linestyle='--', linewidth=2)
plt.scatter(best_epoch_prec + 1, best_val_prec, s=150, c='blue',
            label=f'Best epoch = {best_epoch_prec + 1}', edgecolors='black')
plt.title('Training and Validation Precision', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_auc = np.argmax(val_auc)
best_val_auc = val_auc[best_epoch_auc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_auc, color='red', label='Training AUC', linewidth=2)
plt.plot(epochs, val_auc, color='green', label='Validation AUC', linestyle='--', linewidth=2)
plt.scatter(best_epoch_auc + 1, best_val_auc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_auc + 1}', edgecolors='black')
plt.title('Training and Validation AUC', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
# ==========================================
# Model Evaluation Function
# ==========================================
def evaluate_model(model, test_generator, labels, model_name, batch_size=32):
    """
    Evaluate a trained binary-classification model with dual inputs (image + handcrafted features).

    Args:
        model: Trained Keras model expecting ((img, hf), labels)
        test_generator: HandcraftedGeneratorWrapper instance
        labels: List of class names (e.g., ['Benign', 'Melanoma'])
        model_name: Name for display
        batch_size: Batch size (used for step calculation)

    Returns:
        metrics_dict: Dictionary with all metrics
        auc_curve_data: FPR, TPR for ROC curve plotting
    """

    steps = len(test_generator)

    y_true = []
    y_pred = []
    y_probs = []

    print(f"\n{'='*80}")
    print(f"Evaluating: {model_name}")
    print(f"{'='*80}")
    print(f"Total steps: {steps}")

    # Loop through test generator
    for step_idx in tqdm(range(steps), desc=f"Evaluating {model_name}", total=steps):
        # Get batch from generator
        images, labels_batch = test_generator[step_idx]

        # Predict using both inputs
        preds = model.predict(
            images,
            verbose=0
        )  # sigmoid outputs (probability of class 1)

        preds = preds.reshape(-1)

        y_probs.extend(preds)                      # probability for class 1
        y_pred.extend((preds >= 0.5).astype(int))  # binary classification using threshold 0.5

        # Labels from generator (binary)
        labels_batch = labels_batch.reshape(-1)
        y_true.extend(labels_batch.astype(int))

    # Convert to arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_probs = np.array(y_probs)

    print(f"\nTotal samples evaluated: {len(y_true)}")
    print(f"Class distribution: {np.bincount(y_true)}")

    # Metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    try:
        auc = roc_auc_score(y_true, y_probs)
    except ValueError:
        auc = float("nan")

    # Classification report
    report = classification_report(y_true, y_pred, target_names=labels, zero_division=0)

    # Print metrics
    print(f"\n{'='*80}")
    print(f"PERFORMANCE METRICS")
    print(f"{'='*80}")
    print(f"Accuracy  : {accuracy:.4f}")
    print(f"Precision : {precision:.4f}")
    print(f"Recall    : {recall:.4f}")
    print(f"F1 Score  : {f1:.4f}")
    print(f"AUC       : {auc:.4f}")
    print(f"{'='*80}\n")

    print("Classification Report:\n")
    print(report)

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Greens',
        linewidths=2,
        linecolor='black',
        xticklabels=labels,
        yticklabels=labels,
        annot_kws={"size": 16, "weight": "bold"},
        cbar_kws={"label": "Count"}
    )

    plt.title(f'Confusion Matrix: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_probs)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, 'b-', linewidth=3, label=f'AUC = {auc:.4f}')
    plt.plot([0, 1], [0, 1], 'k--', linewidth=2, label='Random Classifier')
    plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold')
    plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold')
    plt.title(f'ROC Curve: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.legend(fontsize=12, loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.tight_layout()
    plt.show()

    auc_curve_data = {"fpr": fpr, "tpr": tpr, "auc": auc}

    return {
        "model_name": model_name,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "auc": auc,
        "y_true": y_true,
        "y_pred": y_pred,
        "y_probs": y_probs,
        "confusion_matrix": cm
    }, auc_curve_data


# Evaluate
metrics, roc_data = evaluate_model(
    model=model,
    test_generator=test_data,
    labels=['Benign', 'Melanoma'],
    model_name='SkinCancerModel',
    batch_size=32
)

# Access results
print(f"\nTest Accuracy: {metrics['accuracy']:.4f}")
print(f"Test AUC: {metrics['auc']:.4f}")

# Plot ROC curve
fpr, tpr, auc = roc_data['fpr'], roc_data['tpr'], roc_data['auc']
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc:.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()
# Out:
# ================================================================================
# Evaluating: SkinCancerModel
# ================================================================================
# Total steps: 10
# Evaluating SkinCancerModel: 100%|██████████| 10/10 [00:12<00:00,  1.29s/it]
# Total samples evaluated: 300
# Class distribution: [150 150]
#
# ================================================================================
# PERFORMANCE METRICS
# ================================================================================
# Accuracy  : 0.8933
# Precision : 0.9538
# Recall    : 0.8267
# F1 Score  : 0.8857
# AUC       : 0.9680
# ================================================================================
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Benign       0.85      0.96      0.90       150
#     Melanoma       0.95      0.83      0.89       150
#
#     accuracy                           0.89       300
#    macro avg       0.90      0.89      0.89       300
# weighted avg       0.90      0.89      0.89       300
# Test Accuracy: 0.8933
# Test AUC: 0.9680

# %% [markdown]
# ----------------
# Bootstrap 95% Confidence interval

# %%
# -----------------------------
# Parameters
# -----------------------------
B = 1000                # number of bootstrap samples
RNG_SEED = 42

# 1) Get predictions and true labels
probs = model.predict(test_data, verbose=1).ravel()   # shape (N,) after ravel for binary
y_true = np.asarray(test_data.classes)                # shape (N,)
y_pred = (probs >= 0.5).astype(int)                   # thresholding for binary

# Point estimates
point_accuracy = accuracy_score(y_true, y_pred)
point_precision = precision_score(y_true, y_pred, average='binary', zero_division=0)
point_recall = recall_score(y_true, y_pred, average='binary', zero_division=0)
point_f1 = f1_score(y_true, y_pred, average='binary', zero_division=0)

# AUC for binary
try:
    point_auc = roc_auc_score(y_true, probs)
except Exception:
    point_auc = np.nan
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 589ms/step

# %%
# 2) Bootstrap
rng = np.random.RandomState(RNG_SEED)
metrics_boot = {k: [] for k in ["accuracy", "precision", "recall", "f1", "auc"]}
N = len(y_true)

for i in tqdm(range(B), desc="Bootstrap samples"):
    idx = rng.randint(0, N, size=N)   # sample with replacement
    y_true_b, y_pred_b, probs_b = y_true[idx], y_pred[idx], probs[idx]

    metrics_boot["accuracy"].append(accuracy_score(y_true_b, y_pred_b))
    metrics_boot["precision"].append(precision_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["recall"].append(recall_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["f1"].append(f1_score(y_true_b, y_pred_b, average='macro', zero_division=0))

    #probs_b = probs_b.ravel()   # ensure shape (N,)
    
    try:
        auc_b = roc_auc_score(y_true_b, probs_b)
    except Exception:
        auc_b = np.nan
    
    metrics_boot["auc"].append(auc_b)


# Convert lists to arrays
for k in metrics_boot:
    metrics_boot[k] = np.array(metrics_boot[k], dtype=np.float32)
# Out:
# Bootstrap samples: 100%|██████████| 1000/1000 [00:03<00:00, 259.92it/s]

# %%
# 3) Compute 95% CI
def ci95(arr):
    arr = arr[~np.isnan(arr)]
    if len(arr) == 0:
        return (np.nan, np.nan)
    return np.percentile(arr, [2.5, 97.5])

results = []
for name, point in [
    ("accuracy", point_accuracy),
    ("precision", point_precision),
    ("recall", point_recall),
    ("f1", point_f1),
    ("auc", point_auc)
]:
    lo, hi = ci95(metrics_boot[name])
    results.append({
        "metric": name,
        "point_estimate": point,
        "ci_lower": lo,
        "ci_upper": hi,
        "n_boot_valid": int(np.sum(~np.isnan(metrics_boot[name])))
    })

df_results = pd.DataFrame(results).set_index("metric")
pd.set_option("display.float_format", "{:.4f}".format)
print(df_results)
# Out:
#            point_estimate  ci_lower  ci_upper  n_boot_valid
# metric
# accuracy           0.8933    0.8567    0.9267          1000
# precision          0.9538    0.8673    0.9320          1000
# recall             0.8267    0.8585    0.9266          1000
# f1                 0.8857    0.8562    0.9263          1000
# auc                0.9680    0.9509    0.9827          1000

# %%
def plot_bootstrap_metrics(metrics_boot, df_results, n_cols=3, figsize_per_plot=(5, 4),
                           w_pad=0.6, h_pad=1.5, shift_factor=0.5):
    """
    Plot bootstrap metric distributions.

    Args:
        metrics_boot: dict of metric -> bootstrap array
        df_results: DataFrame with point estimates and CIs
        n_cols: 
            >0 -> number of columns for grid layout
             0 -> plot each metric separately (one figure per metric)
        figsize_per_plot: (width, height) per subplot
        w_pad: horizontal gap between subplots (grid mode only)
        h_pad: vertical gap between subplots (grid mode only)
        shift_factor: how much to center last row if not full (grid mode only)
    """

    metrics = list(metrics_boot.keys())
    n_metrics = len(metrics)

    # --------------------
    # Single-plot mode
    # --------------------
    if n_cols == 0:
        for metric in metrics:
            vals = metrics_boot[metric]
            vals_nonan = vals[~np.isnan(vals)]

            fig, ax = plt.subplots(figsize=figsize_per_plot)
            ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
            ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
            ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
            ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

            ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
            ax.legend()
            plt.tight_layout()
            plt.show()
        return  # done

    # --------------------
    # Grid mode
    # --------------------
    n_rows = int(np.ceil(n_metrics / n_cols))

    fig, axes = plt.subplots(n_rows, n_cols,
                             figsize=(figsize_per_plot[0]*n_cols,
                                      figsize_per_plot[1]*n_rows))
    axes = np.array(axes).reshape(-1)  # flatten

    for i, metric in enumerate(metrics):
        ax = axes[i]
        vals = metrics_boot[metric]
        vals_nonan = vals[~np.isnan(vals)]

        ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
        ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
        ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
        ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

        ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
        ax.legend()

        # 🔹 Format x-axis ticks to 2 decimal places
        ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:.2f}"))

    # remove unused axes
    for j in range(n_metrics, len(axes)):
        fig.delaxes(axes[j])

    # ---- Center last row if it's not full ----
    last_row_count = n_metrics % n_cols
    if last_row_count != 0:
        empty_slots = n_cols - last_row_count
        last_row_axes = axes[n_cols*(n_rows-1):n_cols*(n_rows-1)+last_row_count]

        for ax in last_row_axes:
            pos = ax.get_position()
            shift = (empty_slots / n_cols) * shift_factor
            pos_new = [pos.x0 + shift, pos.y0, pos.width, pos.height]
            ax.set_position(pos_new)

    plt.tight_layout(pad=1.0, w_pad=w_pad, h_pad=h_pad)
    plt.show()

# %%
plot_bootstrap_metrics(
    metrics_boot, 
    df_results, 
    n_cols=0,        # number of columns in grid (set 0 for separate plots, 2 or 3 for grid)
    w_pad=0.5,       # horizontal space between columns (increase -> wider gap)
    h_pad=1.0,       # vertical space between rows (increase -> taller gap)
    shift_factor=0.0 # how much to horizontally shift last-row plots for centering
)

# %% [markdown]
# --------------------
# Gradcam ++ (more advance visualization than previous version of mine)
