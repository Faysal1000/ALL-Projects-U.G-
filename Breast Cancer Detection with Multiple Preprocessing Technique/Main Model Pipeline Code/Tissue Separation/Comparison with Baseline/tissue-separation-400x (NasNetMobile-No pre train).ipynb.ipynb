# %%
# === System & OS Utilities ===
import os
import math
import pickle
import sys
import warnings
import random
import logging
warnings.filterwarnings("ignore")
logging.getLogger().setLevel(logging.ERROR)

# === Progress Bar ===
from tqdm import tqdm

# === TensorFlow & Keras ===
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adamax, AdamW
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.layers import Layer
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import (Conv2D, 
                                     Dense,
                                     Dropout,
                                     Flatten,
                                     GlobalAveragePooling2D,
                                     GlobalMaxPooling2D,
                                     MaxPooling2D,
                                     BatchNormalization,
                                     ReLU,
                                     Add)
from tensorflow.keras.layers import (
    Layer, Conv2D, Dense, Dropout,
    GlobalAveragePooling2D, GlobalMaxPooling2D,
    Reshape, Multiply, Add, Activation, Concatenate
)
import os, numpy as np, cv2
from skimage.feature import local_binary_pattern
from tensorflow.keras import layers, Model, initializers
from tensorflow.keras.layers import Layer
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# === Data Handling ===
import numpy as np
import pandas as pd
import cv2

# === Visualization ===
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# === Scikit-learn ===
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, classification_report, confusion_matrix
)

# %%
print("Python version:", sys.version)
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("OpenCV version:", cv2.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# Python version: 3.11.14 (main, Oct 21 2025, 18:27:30) [Clang 20.1.8 ]
# TensorFlow version: 2.16.2
# Keras version: 3.5.0
# NumPy version: 1.26.4
# Pandas version: 2.2.3
# OpenCV version: 4.6.0
# Matplotlib version: 3.7.5
# Seaborn version: 0.12.2
# Scikit-learn version: 1.2.2

# %%
#python version 3.11.11
#!python -m pip install tensorflow==2.18.0 keras==3.5.0 numpy==1.26.4 pandas==2.2.3 opencv-python==4.6.0.66 matplotlib==3.7.5 seaborn==0.12.2 scikit-learn==1.2.2

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPUs detected: {len(gpus)}")
    except RuntimeError as e:
        print(f"Error setting GPU memory growth: {e}")
else:
    print("No GPUs detected.")
# Out:
# GPUs detected: 1

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
EPOCH = 100
img_shape=(*IMG_SIZE,3)
dataset_path = r"/kaggle/input/preprocessed-augmented-breakhis-dataset/preprocessed_breakhis_dataset/tissue_only_normalized"
labels = ['Benign', 'Malignant']
print("Class Names:", labels)
# Out:
# Class Names: ['Benign', 'Malignant']

# %%
def data_frame(root_path, target_folder):

    class_paths = []
    classes = []
    patient_ids = []

    for label in os.listdir(root_path):

        class_dir = os.path.join(root_path, label)
        if not os.path.isdir(class_dir):
            continue

        target_dir = os.path.join(class_dir, target_folder)

        if not os.path.isdir(target_dir):
            print(f"[WARNING] '{target_folder}' not found in class '{label}'. Skipping.")
            continue

        for image in os.listdir(target_dir):

            if not image.lower().endswith(('.png','.jpg','.jpeg')):
                continue

            path = os.path.join(target_dir,image)

            parts = image.split('-')

            # Skip malformed filenames
            if len(parts) < 3:
                print(f"Skipping malformed filename: {image}")
                continue

            patient_id = parts[1] + "-" + parts[2]

            class_paths.append(path)
            classes.append(label)
            patient_ids.append(patient_id)

    df = pd.DataFrame({
        'Class Path': class_paths,
        'Class': classes,
        'PatientID': patient_ids
    })

    return df

# %%
main_frame = data_frame(
    root_path=dataset_path,
    target_folder="400X"   # "40X", "100X", "200X", "400X"
)

patients = main_frame['PatientID'].unique()

train_pat, temp_pat = train_test_split(
    patients,
    test_size=0.20,
    random_state=42
)

val_pat, test_pat = train_test_split(
    temp_pat,
    test_size=0.5,
    random_state=42
)

train_dataframe = main_frame[main_frame['PatientID'].isin(train_pat)]
validation_dataframe = main_frame[main_frame['PatientID'].isin(val_pat)]
test_dataframe = main_frame[main_frame['PatientID'].isin(test_pat)]


print("Train patients:",len(set(train_dataframe.PatientID)))
print("Val patients:",len(set(validation_dataframe.PatientID)))
print("Test patients:",len(set(test_dataframe.PatientID)))

print("Overlap train-val:",set(train_dataframe.PatientID) & set(validation_dataframe.PatientID))
print("Overlap train-test:",set(train_dataframe.PatientID) & set(test_dataframe.PatientID))
print("Overlap val-test:",set(validation_dataframe.PatientID) & set(test_dataframe.PatientID))
print()
train_counts = train_dataframe['Class'].value_counts()
val_counts = validation_dataframe['Class'].value_counts()
test_counts = test_dataframe['Class'].value_counts()

count_table = pd.DataFrame({
    "Train": train_counts,
    "Validation": val_counts,
    "Test": test_counts
}).fillna(0).astype(int)

count_table["Total"] = count_table.sum(axis=1)
grand_total = pd.DataFrame({
    "Train": [count_table["Train"].sum()],
    "Validation": [count_table["Validation"].sum()],
    "Test": [count_table["Test"].sum()],
    "Total": [count_table["Total"].sum()]
}, index=["Total"])
count_table = pd.concat([count_table, grand_total])

print(count_table)

BATCH_SIZE = min(BATCH_SIZE, len(validation_dataframe))
print(f"Batch Size = {BATCH_SIZE}")
# Out:
# Train patients: 64
# Val patients: 8
# Test patients: 9
# Overlap train-val: set()
# Overlap train-test: set()
# Overlap val-test: set()
#
#            Train  Validation  Test  Total
# Benign      1252         186    62   1500
# Malignant   1134         142   224   1500
# Total       2386         328   286   3000
# Batch Size = 32

# %%
# Combine and sum the counts
total_counts = train_counts.add(val_counts, fill_value=0)
total_counts = total_counts.add(test_counts, fill_value=0)
total_counts = total_counts.sort_index()

# Prepare labels with percentages
total = total_counts.sum()
labels_with_percent = [f"{label} ({(count/total)*100:.1f}%)" for label, count in zip(total_counts.index, total_counts.values)]

# Define custom autopct function to show raw count
def make_autopct(values):
    def autopct(pct):
        total = sum(values)
        count = int(round(pct * total / 100.0))
        return f"{count}"
    return autopct

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_counts.values, labels=labels_with_percent, autopct=make_autopct(total_counts.values), startangle=140, textprops={'fontsize': 12})
plt.axis('equal')
plt.show()

# %%
# Count occurrences of each class in train, validation, and test datasets
train_counts = train_dataframe['Class'].value_counts().sort_index()
val_counts = validation_dataframe['Class'].value_counts().sort_index()
test_counts = test_dataframe['Class'].value_counts().sort_index()

# Combine into a DataFrame with the index kept as a column
data_counts = pd.DataFrame({
    'Class': train_counts.index,
    'Train': train_counts.values,
    'Validation': val_counts.values,
    'Test': test_counts.values
}).melt(id_vars='Class', var_name='Dataset', value_name='Count')

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(y='Class', x='Count', hue='Dataset', data=data_counts, 
                 palette=['blue', 'orange', 'green'], orient='h', width=0.6)

# Add count labels to the right of the bars with slight downward offset
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', 
                (p.get_width(), p.get_y() + p.get_height() / 2.0 + 0.05),  # pushed slightly down
                ha='left', va='center', 
                fontsize=10, color='black', 
                xytext=(5, 0), textcoords='offset points')

# Remove borders (spines)
sns.despine(top=True, right=True, left=False, bottom=False)

# Dynamically set the x-axis limits with some extra space on the right
left, right = ax.get_xlim()  # Get current x-limits

# Set the new right limit with a 15% increase
right += (right - left) * 0.15  # Increase right by 15%

# Apply the new limits to the x-axis
ax.set_xlim(left, right)

# Add labels and title
plt.ylabel("Class")
plt.xlabel("Count")
plt.title("Class Distribution in Train, Validation, and Test Sets")

# Move the legend
plt.legend(title="Dataset", loc='upper right', fontsize=8)

# Add grid only along x-axis
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Tidy layout
plt.tight_layout()
plt.show()

# %%
def preprocess_image(image):

    image = image.astype(np.float32)

    min_val = image.min()
    max_val = image.max()

    # avoid division by zero
    if max_val - min_val < 1e-6:
        return np.zeros_like(image, dtype=np.float32)

    # min-max scale to [0, 1]
    image = (image - min_val) / (max_val - min_val)
    
    return image

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,

    # ---- Geometric ----
    rotation_range=30,         
    zoom_range=0.1,           
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,

    horizontal_flip=True,
    vertical_flip=True,

    fill_mode="reflect"
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_image)


train_data = train_datagen.flow_from_dataframe(train_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', seed=42)

validation_data = val_datagen.flow_from_dataframe(validation_dataframe, x_col='Class Path',
                                     y_col='Class', batch_size=BATCH_SIZE,
                                     target_size=IMG_SIZE, class_mode='binary', seed=42)

test_data = test_datagen.flow_from_dataframe(test_dataframe, x_col='Class Path',
                                  y_col='Class', batch_size=BATCH_SIZE,
                                  target_size=IMG_SIZE, class_mode='binary', shuffle=False, seed=42)
# Out:
# Found 2400 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.
# Found 300 validated image filenames belonging to 2 classes.

# %%
class RestoreBestValidationModel(Callback):
    """
    Custom Keras Callback to restore model weights from the best epoch based on validation accuracy.
    - Tracks the best validation accuracy during training.
    - Restores the model weights from the epoch with the best validation accuracy when training finishes.
    """
    
    def __init__(self):
        super(RestoreBestValidationModel, self).__init__()
        # Initialize best validation accuracy, epoch, and weights to track the best model
        self.best_val_acc = -1
        self.best_epoch = -1
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        """
        Callback function executed at the end of each epoch.
        - Compares the current validation accuracy with the best validation accuracy.
        - If the current validation accuracy is higher or tied but at a later epoch, updates the best model weights.
        """
        # Get validation accuracy from logs
        val_acc = logs.get('val_accuracy')
        
        if val_acc is not None:
            # Update the best validation accuracy and weights if the current one is better or at a later epoch
            if val_acc > self.best_val_acc or (val_acc == self.best_val_acc and epoch > self.best_epoch):
                self.best_val_acc = val_acc
                self.best_epoch = epoch
                self.best_weights = self.model.get_weights()  # Store the model's weights
                print(f"\nModel weights updated at epoch {epoch + 1} with val_accuracy: {val_acc:.4f}")

    def on_train_end(self, logs=None):
        """
        Callback function executed at the end of training.
        - Restores the model weights from the epoch with the best validation accuracy.
        """
        # If we found a better model during training, restore the best weights
        if self.best_weights is not None:
            print(f"Restoring model weights from best epoch {self.best_epoch + 1} with val_accuracy: {self.best_val_acc:.4f}")
            self.model.set_weights(self.best_weights)  # Set the weights back to the best model's weights

# Instantiate the callback
restore_best = RestoreBestValidationModel()

# %%
base_model = tf.keras.applications.NASNetMobile(
    input_shape=(224, 224, 3),
    include_top=False,
    weights=None
)

x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)  # optional hidden layer....
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)  
model = tf.keras.Model(inputs=base_model.input, outputs=output)
# Out:
# I0000 00:00:1772989107.157818      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# ===============================
# Dynamic Cosine Decay
# ===============================
num_train_samples = sum(list(train_counts))

steps_per_epoch = math.ceil(num_train_samples / BATCH_SIZE)
decay_steps = steps_per_epoch * EPOCH

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4,
    decay_steps=decay_steps,
    alpha=1e-3   
)

optimizer = tf.keras.optimizers.AdamW(
    learning_rate=lr_schedule,
    weight_decay=5e-5,   
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-7
)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=False),
    metrics=[
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.BinaryAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall")
    ]
)

print("Model compiled with optimized AdamW + CosineDecay")
print(f"Train samples: {num_train_samples}")
print(f"Steps per epoch: {steps_per_epoch}")
print(f"Total decay steps: {decay_steps}")
# Out:
# Model compiled with optimized AdamW + CosineDecay
# Train samples: 2400
# Steps per epoch: 75
# Total decay steps: 7500

# %%
all_steps = np.arange(decay_steps)
lrs = [lr_schedule(step).numpy() for step in all_steps]

# -----------------------------
# Plot
# -----------------------------
plt.figure(figsize=(8,4))
plt.plot(all_steps, lrs)
plt.title("Cosine Decay Learning Rate Schedule")
plt.xlabel("Training Steps")
plt.ylabel("Learning Rate")
plt.grid(True)
plt.show()

# %%
history = model.fit(
    train_data,
    validation_data=validation_data,
    epochs=EPOCH,
    callbacks=[restore_best],
    verbose=1
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772989263.089754      58 service.cc:148] XLA service 0x7d2310007e40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772989263.090669      58 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772989284.045658      58 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1772989342.527211      58 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.7223 - auc: 0.7947 - loss: 0.5415 - precision: 0.7281 - recall: 0.7514
# Model weights updated at epoch 1 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 272s 767ms/step - accuracy: 0.7227 - auc: 0.7952 - loss: 0.5410 - precision: 0.7286 - recall: 0.7513 - val_accuracy: 0.5000 - val_auc: 0.4967 - val_loss: 3.9302 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 2/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.7837 - auc: 0.8697 - loss: 0.4486 - precision: 0.7771 - recall: 0.8105
# Model weights updated at epoch 2 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 418ms/step - accuracy: 0.7838 - auc: 0.8698 - loss: 0.4485 - precision: 0.7771 - recall: 0.8105 - val_accuracy: 0.5000 - val_auc: 0.3398 - val_loss: 2.8706 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 3/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.8113 - auc: 0.8911 - loss: 0.4135 - precision: 0.8014 - recall: 0.8334
# Model weights updated at epoch 3 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.8112 - auc: 0.8911 - loss: 0.4135 - precision: 0.8014 - recall: 0.8333 - val_accuracy: 0.5000 - val_auc: 0.3507 - val_loss: 2.8070 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 4/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.7964 - auc: 0.8910 - loss: 0.4103 - precision: 0.7996 - recall: 0.7905
# Model weights updated at epoch 4 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 428ms/step - accuracy: 0.7965 - auc: 0.8910 - loss: 0.4104 - precision: 0.7996 - recall: 0.7907 - val_accuracy: 0.5000 - val_auc: 0.3625 - val_loss: 2.6680 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 5/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8275 - auc: 0.9110 - loss: 0.3838 - precision: 0.8278 - recall: 0.8307
# Model weights updated at epoch 5 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 428ms/step - accuracy: 0.8275 - auc: 0.9110 - loss: 0.3837 - precision: 0.8278 - recall: 0.8307 - val_accuracy: 0.5000 - val_auc: 0.3502 - val_loss: 1.8816 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 6/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8209 - auc: 0.9118 - loss: 0.3665 - precision: 0.8273 - recall: 0.7993
# Model weights updated at epoch 6 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 423ms/step - accuracy: 0.8209 - auc: 0.9118 - loss: 0.3666 - precision: 0.8273 - recall: 0.7994 - val_accuracy: 0.5000 - val_auc: 0.3446 - val_loss: 1.4444 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 7/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8505 - auc: 0.9241 - loss: 0.3477 - precision: 0.8572 - recall: 0.8427
# Model weights updated at epoch 7 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 425ms/step - accuracy: 0.8503 - auc: 0.9240 - loss: 0.3479 - precision: 0.8571 - recall: 0.8424 - val_accuracy: 0.5000 - val_auc: 0.3062 - val_loss: 1.5061 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8412 - auc: 0.9257 - loss: 0.3497 - precision: 0.8407 - recall: 0.8382
# Model weights updated at epoch 8 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 424ms/step - accuracy: 0.8412 - auc: 0.9257 - loss: 0.3498 - precision: 0.8407 - recall: 0.8382 - val_accuracy: 0.5000 - val_auc: 0.3463 - val_loss: 1.3310 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 9/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8501 - auc: 0.9387 - loss: 0.3161 - precision: 0.8802 - recall: 0.8145
# Model weights updated at epoch 9 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.8500 - auc: 0.9386 - loss: 0.3161 - precision: 0.8799 - recall: 0.8146 - val_accuracy: 0.5000 - val_auc: 0.3541 - val_loss: 1.1308 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 10/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8570 - auc: 0.9321 - loss: 0.3298 - precision: 0.8898 - recall: 0.8263
# Model weights updated at epoch 10 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 428ms/step - accuracy: 0.8569 - auc: 0.9321 - loss: 0.3299 - precision: 0.8895 - recall: 0.8263 - val_accuracy: 0.5000 - val_auc: 0.3788 - val_loss: 0.9423 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 11/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8451 - auc: 0.9290 - loss: 0.3410 - precision: 0.8591 - recall: 0.8252
# Model weights updated at epoch 11 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 423ms/step - accuracy: 0.8453 - auc: 0.9291 - loss: 0.3408 - precision: 0.8593 - recall: 0.8254 - val_accuracy: 0.5000 - val_auc: 0.4847 - val_loss: 0.8620 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 12/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8600 - auc: 0.9407 - loss: 0.3076 - precision: 0.8756 - recall: 0.8402
# Model weights updated at epoch 12 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 428ms/step - accuracy: 0.8600 - auc: 0.9406 - loss: 0.3077 - precision: 0.8756 - recall: 0.8401 - val_accuracy: 0.5000 - val_auc: 0.5601 - val_loss: 0.7799 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 13/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8689 - auc: 0.9459 - loss: 0.2973 - precision: 0.8889 - recall: 0.8441
# Model weights updated at epoch 13 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 418ms/step - accuracy: 0.8688 - auc: 0.9458 - loss: 0.2975 - precision: 0.8888 - recall: 0.8441 - val_accuracy: 0.5000 - val_auc: 0.5965 - val_loss: 0.7938 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 14/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.8645 - auc: 0.9430 - loss: 0.3028 - precision: 0.8822 - recall: 0.8463
# Model weights updated at epoch 14 with val_accuracy: 0.5000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.8645 - auc: 0.9430 - loss: 0.3028 - precision: 0.8823 - recall: 0.8463 - val_accuracy: 0.5000 - val_auc: 0.6434 - val_loss: 0.7265 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 15/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8763 - auc: 0.9487 - loss: 0.2861 - precision: 0.8893 - recall: 0.8528
# Model weights updated at epoch 15 with val_accuracy: 0.5267
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 419ms/step - accuracy: 0.8763 - auc: 0.9487 - loss: 0.2863 - precision: 0.8893 - recall: 0.8528 - val_accuracy: 0.5267 - val_auc: 0.6415 - val_loss: 0.6809 - val_precision: 0.5153 - val_recall: 0.9000
# Epoch 16/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 405ms/step - accuracy: 0.8640 - auc: 0.9474 - loss: 0.2931 - precision: 0.8941 - recall: 0.8321 - val_accuracy: 0.4900 - val_auc: 0.6602 - val_loss: 0.6871 - val_precision: 0.4948 - val_recall: 0.9600
# Epoch 17/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8444 - auc: 0.9312 - loss: 0.3321 - precision: 0.8444 - recall: 0.8268
# Model weights updated at epoch 17 with val_accuracy: 0.5300
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 33s 434ms/step - accuracy: 0.8447 - auc: 0.9314 - loss: 0.3316 - precision: 0.8448 - recall: 0.8271 - val_accuracy: 0.5300 - val_auc: 0.6751 - val_loss: 0.6773 - val_precision: 0.5160 - val_recall: 0.9667
# Epoch 18/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8788 - auc: 0.9528 - loss: 0.2752 - precision: 0.8826 - recall: 0.8722
# Model weights updated at epoch 18 with val_accuracy: 0.5967
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 424ms/step - accuracy: 0.8788 - auc: 0.9528 - loss: 0.2752 - precision: 0.8827 - recall: 0.8721 - val_accuracy: 0.5967 - val_auc: 0.7594 - val_loss: 0.6640 - val_precision: 0.9677 - val_recall: 0.2000
# Epoch 19/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.8837 - auc: 0.9521 - loss: 0.2794 - precision: 0.8986 - recall: 0.8599
# Model weights updated at epoch 19 with val_accuracy: 0.6767
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.8838 - auc: 0.9521 - loss: 0.2792 - precision: 0.8986 - recall: 0.8601 - val_accuracy: 0.6767 - val_auc: 0.7455 - val_loss: 0.6609 - val_precision: 0.8046 - val_recall: 0.4667
# Epoch 20/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.8676 - auc: 0.9502 - loss: 0.2806 - precision: 0.8869 - recall: 0.8400 - val_accuracy: 0.5400 - val_auc: 0.7921 - val_loss: 0.6722 - val_precision: 1.0000 - val_recall: 0.0800
# Epoch 21/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.8917 - auc: 0.9639 - loss: 0.2394 - precision: 0.9070 - recall: 0.8735 - val_accuracy: 0.5867 - val_auc: 0.7682 - val_loss: 0.6648 - val_precision: 1.0000 - val_recall: 0.1733
# Epoch 22/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 408ms/step - accuracy: 0.8873 - auc: 0.9589 - loss: 0.2590 - precision: 0.9116 - recall: 0.8623 - val_accuracy: 0.5533 - val_auc: 0.7674 - val_loss: 0.6689 - val_precision: 1.0000 - val_recall: 0.1067
# Epoch 23/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.8861 - auc: 0.9569 - loss: 0.2661 - precision: 0.9207 - recall: 0.8490 - val_accuracy: 0.5267 - val_auc: 0.7685 - val_loss: 0.6737 - val_precision: 1.0000 - val_recall: 0.0533
# Epoch 24/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 404ms/step - accuracy: 0.8785 - auc: 0.9526 - loss: 0.2784 - precision: 0.8904 - recall: 0.8576 - val_accuracy: 0.5433 - val_auc: 0.7684 - val_loss: 0.6705 - val_precision: 0.8824 - val_recall: 0.1000
# Epoch 25/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.8968 - auc: 0.9691 - loss: 0.2293 - precision: 0.9085 - recall: 0.8828 - val_accuracy: 0.5000 - val_auc: 0.7495 - val_loss: 0.6889 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.8997 - auc: 0.9618 - loss: 0.2432 - precision: 0.9221 - recall: 0.8737 - val_accuracy: 0.5000 - val_auc: 0.7322 - val_loss: 0.6857 - val_precision: 0.5000 - val_recall: 0.0067
# Epoch 27/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 405ms/step - accuracy: 0.9035 - auc: 0.9670 - loss: 0.2313 - precision: 0.9113 - recall: 0.8899 - val_accuracy: 0.5000 - val_auc: 0.7407 - val_loss: 0.6868 - val_precision: 0.5000 - val_recall: 0.0133
# Epoch 28/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.8908 - auc: 0.9590 - loss: 0.2550 - precision: 0.9132 - recall: 0.8605 - val_accuracy: 0.5000 - val_auc: 0.7261 - val_loss: 0.6937 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.9088 - auc: 0.9682 - loss: 0.2290 - precision: 0.9125 - recall: 0.9056 - val_accuracy: 0.5033 - val_auc: 0.7128 - val_loss: 0.6977 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 30/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.9147 - auc: 0.9738 - loss: 0.2046 - precision: 0.9248 - recall: 0.9016 - val_accuracy: 0.5000 - val_auc: 0.7070 - val_loss: 0.7173 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 405ms/step - accuracy: 0.9112 - auc: 0.9726 - loss: 0.2133 - precision: 0.9119 - recall: 0.9082 - val_accuracy: 0.5000 - val_auc: 0.6854 - val_loss: 0.7727 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.9125 - auc: 0.9745 - loss: 0.2038 - precision: 0.9192 - recall: 0.8973 - val_accuracy: 0.5000 - val_auc: 0.6693 - val_loss: 0.7437 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.8887 - auc: 0.9654 - loss: 0.2372 - precision: 0.8894 - recall: 0.8866 - val_accuracy: 0.5000 - val_auc: 0.6651 - val_loss: 0.8260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.9231 - auc: 0.9792 - loss: 0.1852 - precision: 0.9226 - recall: 0.9172 - val_accuracy: 0.5000 - val_auc: 0.6746 - val_loss: 0.8194 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9059 - auc: 0.9719 - loss: 0.2161 - precision: 0.9052 - recall: 0.9033 - val_accuracy: 0.5000 - val_auc: 0.6559 - val_loss: 0.8847 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.9182 - auc: 0.9757 - loss: 0.1994 - precision: 0.9149 - recall: 0.9180 - val_accuracy: 0.5000 - val_auc: 0.6800 - val_loss: 0.8384 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9262 - auc: 0.9803 - loss: 0.1787 - precision: 0.9299 - recall: 0.9185 - val_accuracy: 0.5000 - val_auc: 0.6683 - val_loss: 0.7933 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9224 - auc: 0.9786 - loss: 0.1887 - precision: 0.9405 - recall: 0.9050 - val_accuracy: 0.5000 - val_auc: 0.6417 - val_loss: 0.8012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9193 - auc: 0.9774 - loss: 0.1914 - precision: 0.9329 - recall: 0.8996 - val_accuracy: 0.5000 - val_auc: 0.6434 - val_loss: 0.7687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9167 - auc: 0.9762 - loss: 0.1964 - precision: 0.9220 - recall: 0.9122 - val_accuracy: 0.5033 - val_auc: 0.6394 - val_loss: 0.7751 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 41/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.9327 - auc: 0.9827 - loss: 0.1671 - precision: 0.9407 - recall: 0.9189 - val_accuracy: 0.5000 - val_auc: 0.5986 - val_loss: 0.7878 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9271 - auc: 0.9811 - loss: 0.1761 - precision: 0.9370 - recall: 0.9142 - val_accuracy: 0.5033 - val_auc: 0.5936 - val_loss: 0.7499 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 43/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.9279 - auc: 0.9839 - loss: 0.1643 - precision: 0.9350 - recall: 0.9173 - val_accuracy: 0.5000 - val_auc: 0.5816 - val_loss: 0.7463 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9269 - auc: 0.9816 - loss: 0.1727 - precision: 0.9370 - recall: 0.9162 - val_accuracy: 0.5033 - val_auc: 0.5714 - val_loss: 0.7343 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 45/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 417ms/step - accuracy: 0.9458 - auc: 0.9883 - loss: 0.1410 - precision: 0.9543 - recall: 0.9390 - val_accuracy: 0.5033 - val_auc: 0.5598 - val_loss: 0.7539 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 46/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 418ms/step - accuracy: 0.9353 - auc: 0.9877 - loss: 0.1421 - precision: 0.9399 - recall: 0.9300 - val_accuracy: 0.5000 - val_auc: 0.5357 - val_loss: 0.7544 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 421ms/step - accuracy: 0.9347 - auc: 0.9861 - loss: 0.1512 - precision: 0.9518 - recall: 0.9093 - val_accuracy: 0.5033 - val_auc: 0.5420 - val_loss: 0.7368 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 48/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 420ms/step - accuracy: 0.9399 - auc: 0.9899 - loss: 0.1314 - precision: 0.9422 - recall: 0.9376 - val_accuracy: 0.5033 - val_auc: 0.5352 - val_loss: 0.7445 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 49/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.9495 - auc: 0.9891 - loss: 0.1361 - precision: 0.9423 - recall: 0.9577 - val_accuracy: 0.5033 - val_auc: 0.5622 - val_loss: 0.7422 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 50/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 423ms/step - accuracy: 0.9320 - auc: 0.9858 - loss: 0.1532 - precision: 0.9392 - recall: 0.9278 - val_accuracy: 0.5033 - val_auc: 0.5688 - val_loss: 0.7386 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 51/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9350 - auc: 0.9885 - loss: 0.1378 - precision: 0.9441 - recall: 0.9306 - val_accuracy: 0.5000 - val_auc: 0.5459 - val_loss: 0.7605 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9425 - auc: 0.9891 - loss: 0.1334 - precision: 0.9614 - recall: 0.9234 - val_accuracy: 0.5000 - val_auc: 0.6019 - val_loss: 0.7820 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9514 - auc: 0.9908 - loss: 0.1246 - precision: 0.9548 - recall: 0.9465 - val_accuracy: 0.5000 - val_auc: 0.6091 - val_loss: 0.7563 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9481 - auc: 0.9887 - loss: 0.1333 - precision: 0.9502 - recall: 0.9442 - val_accuracy: 0.5000 - val_auc: 0.6259 - val_loss: 0.7729 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 418ms/step - accuracy: 0.9583 - auc: 0.9935 - loss: 0.1076 - precision: 0.9593 - recall: 0.9596 - val_accuracy: 0.5000 - val_auc: 0.6590 - val_loss: 0.7698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9481 - auc: 0.9904 - loss: 0.1266 - precision: 0.9623 - recall: 0.9331 - val_accuracy: 0.5000 - val_auc: 0.6862 - val_loss: 0.7648 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9516 - auc: 0.9918 - loss: 0.1161 - precision: 0.9527 - recall: 0.9498 - val_accuracy: 0.5000 - val_auc: 0.7024 - val_loss: 0.7223 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 404ms/step - accuracy: 0.9508 - auc: 0.9899 - loss: 0.1274 - precision: 0.9626 - recall: 0.9358 - val_accuracy: 0.5000 - val_auc: 0.7183 - val_loss: 0.7326 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.9582 - auc: 0.9896 - loss: 0.1274 - precision: 0.9666 - recall: 0.9492 - val_accuracy: 0.5000 - val_auc: 0.7203 - val_loss: 0.7428 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.9545 - auc: 0.9928 - loss: 0.1106 - precision: 0.9596 - recall: 0.9501 - val_accuracy: 0.5000 - val_auc: 0.7326 - val_loss: 0.7326 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9521 - auc: 0.9898 - loss: 0.1261 - precision: 0.9573 - recall: 0.9472 - val_accuracy: 0.5000 - val_auc: 0.7331 - val_loss: 0.7485 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9569 - auc: 0.9925 - loss: 0.1112 - precision: 0.9624 - recall: 0.9510 - val_accuracy: 0.5000 - val_auc: 0.7384 - val_loss: 0.7477 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9609 - auc: 0.9950 - loss: 0.0968 - precision: 0.9656 - recall: 0.9551 - val_accuracy: 0.5000 - val_auc: 0.7368 - val_loss: 0.7545 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 401ms/step - accuracy: 0.9553 - auc: 0.9921 - loss: 0.1144 - precision: 0.9522 - recall: 0.9594 - val_accuracy: 0.5000 - val_auc: 0.7368 - val_loss: 0.7516 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.9502 - auc: 0.9924 - loss: 0.1146 - precision: 0.9516 - recall: 0.9478 - val_accuracy: 0.5000 - val_auc: 0.7409 - val_loss: 0.7662 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 406ms/step - accuracy: 0.9490 - auc: 0.9912 - loss: 0.1188 - precision: 0.9596 - recall: 0.9379 - val_accuracy: 0.5000 - val_auc: 0.7365 - val_loss: 0.7763 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 408ms/step - accuracy: 0.9508 - auc: 0.9921 - loss: 0.1166 - precision: 0.9613 - recall: 0.9387 - val_accuracy: 0.5000 - val_auc: 0.7457 - val_loss: 0.7856 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 417ms/step - accuracy: 0.9601 - auc: 0.9941 - loss: 0.0982 - precision: 0.9772 - recall: 0.9448 - val_accuracy: 0.5000 - val_auc: 0.7332 - val_loss: 0.7979 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9568 - auc: 0.9938 - loss: 0.1047 - precision: 0.9667 - recall: 0.9477 - val_accuracy: 0.5000 - val_auc: 0.7432 - val_loss: 0.7697 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.9669 - auc: 0.9948 - loss: 0.0981 - precision: 0.9703 - recall: 0.9622 - val_accuracy: 0.5000 - val_auc: 0.7439 - val_loss: 0.7966 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 71/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 420ms/step - accuracy: 0.9614 - auc: 0.9946 - loss: 0.0941 - precision: 0.9663 - recall: 0.9578 - val_accuracy: 0.5000 - val_auc: 0.7369 - val_loss: 0.8306 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9717 - auc: 0.9965 - loss: 0.0808 - precision: 0.9760 - recall: 0.9667 - val_accuracy: 0.5000 - val_auc: 0.7408 - val_loss: 0.8186 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 73/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9722 - auc: 0.9950 - loss: 0.0899 - precision: 0.9718 - recall: 0.9728 - val_accuracy: 0.5000 - val_auc: 0.7402 - val_loss: 0.8284 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9639 - auc: 0.9939 - loss: 0.0971 - precision: 0.9685 - recall: 0.9609 - val_accuracy: 0.5000 - val_auc: 0.7372 - val_loss: 0.8372 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 75/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 33s 431ms/step - accuracy: 0.9703 - auc: 0.9971 - loss: 0.0770 - precision: 0.9787 - recall: 0.9623 - val_accuracy: 0.5000 - val_auc: 0.7461 - val_loss: 0.8160 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 76/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 422ms/step - accuracy: 0.9641 - auc: 0.9962 - loss: 0.0809 - precision: 0.9703 - recall: 0.9577 - val_accuracy: 0.5000 - val_auc: 0.7383 - val_loss: 0.8258 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 77/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 418ms/step - accuracy: 0.9706 - auc: 0.9959 - loss: 0.0803 - precision: 0.9740 - recall: 0.9677 - val_accuracy: 0.5000 - val_auc: 0.7365 - val_loss: 0.8268 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 78/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 417ms/step - accuracy: 0.9599 - auc: 0.9958 - loss: 0.0857 - precision: 0.9644 - recall: 0.9534 - val_accuracy: 0.5000 - val_auc: 0.7385 - val_loss: 0.8163 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9716 - auc: 0.9970 - loss: 0.0724 - precision: 0.9735 - recall: 0.9710 - val_accuracy: 0.5000 - val_auc: 0.7349 - val_loss: 0.8241 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 80/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.9666 - auc: 0.9957 - loss: 0.0849 - precision: 0.9641 - recall: 0.9668 - val_accuracy: 0.5000 - val_auc: 0.7296 - val_loss: 0.8325 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 81/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 415ms/step - accuracy: 0.9733 - auc: 0.9967 - loss: 0.0740 - precision: 0.9760 - recall: 0.9683 - val_accuracy: 0.5000 - val_auc: 0.7258 - val_loss: 0.8278 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 82/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 421ms/step - accuracy: 0.9739 - auc: 0.9964 - loss: 0.0785 - precision: 0.9707 - recall: 0.9767 - val_accuracy: 0.5000 - val_auc: 0.7241 - val_loss: 0.8310 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 83/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9562 - auc: 0.9936 - loss: 0.1032 - precision: 0.9644 - recall: 0.9511 - val_accuracy: 0.5000 - val_auc: 0.7232 - val_loss: 0.8371 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 84/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 416ms/step - accuracy: 0.9742 - auc: 0.9962 - loss: 0.0797 - precision: 0.9725 - recall: 0.9751 - val_accuracy: 0.5000 - val_auc: 0.7187 - val_loss: 0.8361 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 85/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 414ms/step - accuracy: 0.9681 - auc: 0.9956 - loss: 0.0831 - precision: 0.9645 - recall: 0.9688 - val_accuracy: 0.5000 - val_auc: 0.7176 - val_loss: 0.8429 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 86/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 417ms/step - accuracy: 0.9784 - auc: 0.9984 - loss: 0.0588 - precision: 0.9751 - recall: 0.9827 - val_accuracy: 0.5000 - val_auc: 0.7178 - val_loss: 0.8400 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 87/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.9694 - auc: 0.9962 - loss: 0.0752 - precision: 0.9710 - recall: 0.9676 - val_accuracy: 0.5000 - val_auc: 0.7159 - val_loss: 0.8343 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 88/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 400ms/step - accuracy: 0.9683 - auc: 0.9970 - loss: 0.0743 - precision: 0.9685 - recall: 0.9664 - val_accuracy: 0.5000 - val_auc: 0.7146 - val_loss: 0.8311 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 89/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9660 - auc: 0.9974 - loss: 0.0701 - precision: 0.9740 - recall: 0.9590 - val_accuracy: 0.5000 - val_auc: 0.7111 - val_loss: 0.8375 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 90/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9762 - auc: 0.9979 - loss: 0.0658 - precision: 0.9820 - recall: 0.9711 - val_accuracy: 0.5000 - val_auc: 0.7138 - val_loss: 0.8360 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 91/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.9716 - auc: 0.9971 - loss: 0.0728 - precision: 0.9666 - recall: 0.9760 - val_accuracy: 0.5000 - val_auc: 0.7129 - val_loss: 0.8366 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 92/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.9646 - auc: 0.9965 - loss: 0.0808 - precision: 0.9628 - recall: 0.9671 - val_accuracy: 0.5000 - val_auc: 0.7125 - val_loss: 0.8416 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 93/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 418ms/step - accuracy: 0.9651 - auc: 0.9960 - loss: 0.0825 - precision: 0.9570 - recall: 0.9719 - val_accuracy: 0.5000 - val_auc: 0.7114 - val_loss: 0.8441 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 94/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 411ms/step - accuracy: 0.9688 - auc: 0.9971 - loss: 0.0721 - precision: 0.9683 - recall: 0.9689 - val_accuracy: 0.5000 - val_auc: 0.7122 - val_loss: 0.8437 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 95/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 32s 419ms/step - accuracy: 0.9710 - auc: 0.9963 - loss: 0.0808 - precision: 0.9745 - recall: 0.9685 - val_accuracy: 0.5000 - val_auc: 0.7110 - val_loss: 0.8455 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 96/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 409ms/step - accuracy: 0.9691 - auc: 0.9965 - loss: 0.0777 - precision: 0.9733 - recall: 0.9658 - val_accuracy: 0.5000 - val_auc: 0.7116 - val_loss: 0.8450 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 97/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 413ms/step - accuracy: 0.9670 - auc: 0.9956 - loss: 0.0859 - precision: 0.9696 - recall: 0.9637 - val_accuracy: 0.5000 - val_auc: 0.7119 - val_loss: 0.8462 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 98/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 407ms/step - accuracy: 0.9750 - auc: 0.9969 - loss: 0.0743 - precision: 0.9710 - recall: 0.9780 - val_accuracy: 0.5033 - val_auc: 0.7113 - val_loss: 0.8479 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 99/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 410ms/step - accuracy: 0.9739 - auc: 0.9965 - loss: 0.0745 - precision: 0.9769 - recall: 0.9691 - val_accuracy: 0.5033 - val_auc: 0.7119 - val_loss: 0.8492 - val_precision: 1.0000 - val_recall: 0.0067
# Epoch 100/100
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 412ms/step - accuracy: 0.9725 - auc: 0.9971 - loss: 0.0726 - precision: 0.9721 - recall: 0.9741 - val_accuracy: 0.5033 - val_auc: 0.7122 - val_loss: 0.8501 - val_precision: 1.0000 - val_recall: 0.0067
# Restoring model weights from best epoch 19 with val_accuracy: 0.6767

# %%
model.save("Proposed_Model.keras")

# %%
# Save history
with open('training_history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
model = load_model('Proposed_Model.keras')

# %%
# Load history
with open('training_history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
epochs = range(1, len(history['loss']) + 1)

# Training and validation metrics
tr_loss = history['loss']
val_loss = history['val_loss']
tr_acc = history['accuracy']
val_acc = history['val_accuracy']
tr_precision = history['precision']
val_precision = history['val_precision']
tr_auc = history['auc']
val_auc = history['val_auc']

# %%
def print_best_metrics(metric_name, train, val):
    best_epoch = np.argmax(val) + 1
    print(f"📌 Best {metric_name} at epoch {best_epoch}:")
    print(f"   - Train {metric_name}: {abs(train[best_epoch - 1]):.4f}")
    print(f"   - Val {metric_name}:   {abs(val[best_epoch - 1]):.4f}\n")

print_best_metrics("Accuracy", tr_acc, val_acc)
print_best_metrics("Precision", tr_precision, val_precision)
print_best_metrics("AUC", tr_auc, val_auc)
print_best_metrics("Loss", [-x for x in tr_loss], [-x for x in val_loss])  # inverted for max-based search
# Out:
# 📌 Best Accuracy at epoch 19:
#    - Train Accuracy: 0.8888
#    - Val Accuracy:   0.6767
#
# 📌 Best Precision at epoch 20:
#    - Train Precision: 0.8985
#    - Val Precision:   1.0000
#
# 📌 Best AUC at epoch 20:
#    - Train AUC: 0.9517
#    - Val AUC:   0.7921
#
# 📌 Best Loss at epoch 19:
#    - Train Loss: 0.2672
#    - Val Loss:   0.6609

# %%
best_epoch_loss = np.argmin(val_loss)
best_val_loss = val_loss[best_epoch_loss]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_loss, color='red', label='Training Loss', linewidth=2)
plt.plot(epochs, val_loss, color='green', label='Validation Loss', linestyle='--', linewidth=2)
plt.scatter(best_epoch_loss + 1, best_val_loss, s=150, c='blue',
            label=f'Best epoch = {best_epoch_loss + 1}', edgecolors='black')
plt.title('Training and Validation Loss', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_acc = np.argmax(val_acc)
best_val_acc = val_acc[best_epoch_acc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_acc, color='red', label='Training Accuracy', linewidth=2)
plt.plot(epochs, val_acc, color='green', label='Validation Accuracy', linestyle='--', linewidth=2)
plt.scatter(best_epoch_acc + 1, best_val_acc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_acc + 1}', edgecolors='black')
plt.title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_prec = np.argmax(val_precision)
best_val_prec = val_precision[best_epoch_prec]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_precision, color='red', label='Training Precision', linewidth=2)
plt.plot(epochs, val_precision, color='green', label='Validation Precision', linestyle='--', linewidth=2)
plt.scatter(best_epoch_prec + 1, best_val_prec, s=150, c='blue',
            label=f'Best epoch = {best_epoch_prec + 1}', edgecolors='black')
plt.title('Training and Validation Precision', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Precision', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
best_epoch_auc = np.argmax(val_auc)
best_val_auc = val_auc[best_epoch_auc]

plt.figure(figsize=(10, 6))
plt.plot(epochs, tr_auc, color='red', label='Training AUC', linewidth=2)
plt.plot(epochs, val_auc, color='green', label='Validation AUC', linestyle='--', linewidth=2)
plt.scatter(best_epoch_auc + 1, best_val_auc, s=150, c='blue',
            label=f'Best epoch = {best_epoch_auc + 1}', edgecolors='black')
plt.title('Training and Validation AUC', fontsize=14, fontweight='bold')
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('AUC', fontsize=12)
plt.legend(fontsize=10)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.show()

# %%
# ==========================================
# Model Evaluation Function
# ==========================================
def evaluate_model(model, test_generator, labels, model_name, batch_size=32):
    """
    Evaluate a trained binary-classification model with dual inputs (image + handcrafted features).

    Args:
        model: Trained Keras model expecting ((img, hf), labels)
        test_generator: HandcraftedGeneratorWrapper instance
        labels: List of class names (e.g., ['Benign', 'Melanoma'])
        model_name: Name for display
        batch_size: Batch size (used for step calculation)

    Returns:
        metrics_dict: Dictionary with all metrics
        auc_curve_data: FPR, TPR for ROC curve plotting
    """

    steps = len(test_generator)

    y_true = []
    y_pred = []
    y_probs = []

    print(f"\n{'='*80}")
    print(f"Evaluating: {model_name}")
    print(f"{'='*80}")
    print(f"Total steps: {steps}")

    # Loop through test generator
    for step_idx in tqdm(range(steps), desc=f"Evaluating {model_name}", total=steps):
        # Get batch from generator
        images, labels_batch = test_generator[step_idx]

        # Predict using both inputs
        preds = model.predict(
            images,
            verbose=0
        )  # sigmoid outputs (probability of class 1)

        preds = preds.reshape(-1)

        y_probs.extend(preds)                      # probability for class 1
        y_pred.extend((preds >= 0.5).astype(int))  # binary classification using threshold 0.5

        # Labels from generator (binary)
        labels_batch = labels_batch.reshape(-1)
        y_true.extend(labels_batch.astype(int))

    # Convert to arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_probs = np.array(y_probs)

    print(f"\nTotal samples evaluated: {len(y_true)}")
    print(f"Class distribution: {np.bincount(y_true)}")

    # Metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    try:
        auc = roc_auc_score(y_true, y_probs)
    except ValueError:
        auc = float("nan")

    # Classification report
    report = classification_report(y_true, y_pred, target_names=labels, zero_division=0)

    # Print metrics
    print(f"\n{'='*80}")
    print(f"PERFORMANCE METRICS")
    print(f"{'='*80}")
    print(f"Accuracy  : {accuracy:.4f}")
    print(f"Precision : {precision:.4f}")
    print(f"Recall    : {recall:.4f}")
    print(f"F1 Score  : {f1:.4f}")
    print(f"AUC       : {auc:.4f}")
    print(f"{'='*80}\n")

    print("Classification Report:\n")
    print(report)

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Greens',
        linewidths=2,
        linecolor='black',
        xticklabels=labels,
        yticklabels=labels,
        annot_kws={"size": 16, "weight": "bold"},
        cbar_kws={"label": "Count"}
    )

    plt.title(f'Confusion Matrix: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.tight_layout()
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_probs)

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, 'b-', linewidth=3, label=f'AUC = {auc:.4f}')
    plt.plot([0, 1], [0, 1], 'k--', linewidth=2, label='Random Classifier')
    plt.xlabel('False Positive Rate', fontsize=14, fontweight='bold')
    plt.ylabel('True Positive Rate', fontsize=14, fontweight='bold')
    plt.title(f'ROC Curve: {model_name}', fontsize=16, fontweight='bold', pad=20)
    plt.legend(fontsize=12, loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.tight_layout()
    plt.show()

    auc_curve_data = {"fpr": fpr, "tpr": tpr, "auc": auc}

    return {
        "model_name": model_name,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "auc": auc,
        "y_true": y_true,
        "y_pred": y_pred,
        "y_probs": y_probs,
        "confusion_matrix": cm
    }, auc_curve_data


# Evaluate
metrics, roc_data = evaluate_model(
    model=model,
    test_generator=test_data,
    labels=['Benign', 'Melanoma'],
    model_name='SkinCancerModel',
    batch_size=32
)

# Access results
print(f"\nTest Accuracy: {metrics['accuracy']:.4f}")
print(f"Test AUC: {metrics['auc']:.4f}")

# Plot ROC curve
fpr, tpr, auc = roc_data['fpr'], roc_data['tpr'], roc_data['auc']
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, 'b-', linewidth=2, label=f'AUC = {auc:.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()
# Out:
# ================================================================================
# Evaluating: SkinCancerModel
# ================================================================================
# Total steps: 10
# Evaluating SkinCancerModel: 100%|██████████| 10/10 [00:25<00:00,  2.56s/it]
# Total samples evaluated: 300
# Class distribution: [150 150]
#
# ================================================================================
# PERFORMANCE METRICS
# ================================================================================
# Accuracy  : 0.6633
# Precision : 0.7882
# Recall    : 0.4467
# F1 Score  : 0.5702
# AUC       : 0.7407
# ================================================================================
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       Benign       0.61      0.88      0.72       150
#     Melanoma       0.79      0.45      0.57       150
#
#     accuracy                           0.66       300
#    macro avg       0.70      0.66      0.65       300
# weighted avg       0.70      0.66      0.65       300
# Test Accuracy: 0.6633
# Test AUC: 0.7407

# %% [markdown]
# ----------------
# Bootstrap 95% Confidence interval

# %%
# -----------------------------
# Parameters
# -----------------------------
B = 1000                # number of bootstrap samples
RNG_SEED = 42

# 1) Get predictions and true labels
probs = model.predict(test_data, verbose=1).ravel()   # shape (N,) after ravel for binary
y_true = np.asarray(test_data.classes)                # shape (N,)
y_pred = (probs >= 0.5).astype(int)                   # thresholding for binary

# Point estimates
point_accuracy = accuracy_score(y_true, y_pred)
point_precision = precision_score(y_true, y_pred, average='binary', zero_division=0)
point_recall = recall_score(y_true, y_pred, average='binary', zero_division=0)
point_f1 = f1_score(y_true, y_pred, average='binary', zero_division=0)

# AUC for binary
try:
    point_auc = roc_auc_score(y_true, probs)
except Exception:
    point_auc = np.nan
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step

# %%
# 2) Bootstrap
rng = np.random.RandomState(RNG_SEED)
metrics_boot = {k: [] for k in ["accuracy", "precision", "recall", "f1", "auc"]}
N = len(y_true)

for i in tqdm(range(B), desc="Bootstrap samples"):
    idx = rng.randint(0, N, size=N)   # sample with replacement
    y_true_b, y_pred_b, probs_b = y_true[idx], y_pred[idx], probs[idx]

    metrics_boot["accuracy"].append(accuracy_score(y_true_b, y_pred_b))
    metrics_boot["precision"].append(precision_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["recall"].append(recall_score(y_true_b, y_pred_b, average='macro', zero_division=0))
    metrics_boot["f1"].append(f1_score(y_true_b, y_pred_b, average='macro', zero_division=0))

    #probs_b = probs_b.ravel()   # ensure shape (N,)
    
    try:
        auc_b = roc_auc_score(y_true_b, probs_b)
    except Exception:
        auc_b = np.nan
    
    metrics_boot["auc"].append(auc_b)


# Convert lists to arrays
for k in metrics_boot:
    metrics_boot[k] = np.array(metrics_boot[k], dtype=np.float32)
# Out:
# Bootstrap samples: 100%|██████████| 1000/1000 [00:04<00:00, 243.35it/s]

# %%
# 3) Compute 95% CI
def ci95(arr):
    arr = arr[~np.isnan(arr)]
    if len(arr) == 0:
        return (np.nan, np.nan)
    return np.percentile(arr, [2.5, 97.5])

results = []
for name, point in [
    ("accuracy", point_accuracy),
    ("precision", point_precision),
    ("recall", point_recall),
    ("f1", point_f1),
    ("auc", point_auc)
]:
    lo, hi = ci95(metrics_boot[name])
    results.append({
        "metric": name,
        "point_estimate": point,
        "ci_lower": lo,
        "ci_upper": hi,
        "n_boot_valid": int(np.sum(~np.isnan(metrics_boot[name])))
    })

df_results = pd.DataFrame(results).set_index("metric")
pd.set_option("display.float_format", "{:.4f}".format)
print(df_results)
# Out:
#            point_estimate  ci_lower  ci_upper  n_boot_valid
# metric
# accuracy           0.6633    0.6100    0.7167          1000
# precision          0.7882    0.6443    0.7540          1000
# recall             0.4467    0.6168    0.7118          1000
# f1                 0.5702    0.5903    0.6997          1000
# auc                0.7407    0.6856    0.7930          1000

# %%
def plot_bootstrap_metrics(metrics_boot, df_results, n_cols=3, figsize_per_plot=(5, 4),
                           w_pad=0.6, h_pad=1.5, shift_factor=0.5):
    """
    Plot bootstrap metric distributions.

    Args:
        metrics_boot: dict of metric -> bootstrap array
        df_results: DataFrame with point estimates and CIs
        n_cols: 
            >0 -> number of columns for grid layout
             0 -> plot each metric separately (one figure per metric)
        figsize_per_plot: (width, height) per subplot
        w_pad: horizontal gap between subplots (grid mode only)
        h_pad: vertical gap between subplots (grid mode only)
        shift_factor: how much to center last row if not full (grid mode only)
    """

    metrics = list(metrics_boot.keys())
    n_metrics = len(metrics)

    # --------------------
    # Single-plot mode
    # --------------------
    if n_cols == 0:
        for metric in metrics:
            vals = metrics_boot[metric]
            vals_nonan = vals[~np.isnan(vals)]

            fig, ax = plt.subplots(figsize=figsize_per_plot)
            ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
            ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
            ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
            ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

            ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
            ax.legend()
            plt.tight_layout()
            plt.show()
        return  # done

    # --------------------
    # Grid mode
    # --------------------
    n_rows = int(np.ceil(n_metrics / n_cols))

    fig, axes = plt.subplots(n_rows, n_cols,
                             figsize=(figsize_per_plot[0]*n_cols,
                                      figsize_per_plot[1]*n_rows))
    axes = np.array(axes).reshape(-1)  # flatten

    for i, metric in enumerate(metrics):
        ax = axes[i]
        vals = metrics_boot[metric]
        vals_nonan = vals[~np.isnan(vals)]

        ax.hist(vals_nonan, bins=40, alpha=0.8, color="skyblue", edgecolor="k")
        ax.axvline(np.nanpercentile(vals_nonan, 50), color='k', linestyle='--', label='median')
        ax.axvline(df_results.loc[metric, "ci_lower"], color='r', linestyle='-')
        ax.axvline(df_results.loc[metric, "ci_upper"], color='r', linestyle='-', label='95% CI')

        ax.set_title(f"{metric}\npt={df_results.loc[metric,'point_estimate']:.3f}")
        ax.legend()

        # 🔹 Format x-axis ticks to 2 decimal places
        ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:.2f}"))

    # remove unused axes
    for j in range(n_metrics, len(axes)):
        fig.delaxes(axes[j])

    # ---- Center last row if it's not full ----
    last_row_count = n_metrics % n_cols
    if last_row_count != 0:
        empty_slots = n_cols - last_row_count
        last_row_axes = axes[n_cols*(n_rows-1):n_cols*(n_rows-1)+last_row_count]

        for ax in last_row_axes:
            pos = ax.get_position()
            shift = (empty_slots / n_cols) * shift_factor
            pos_new = [pos.x0 + shift, pos.y0, pos.width, pos.height]
            ax.set_position(pos_new)

    plt.tight_layout(pad=1.0, w_pad=w_pad, h_pad=h_pad)
    plt.show()

# %%
plot_bootstrap_metrics(
    metrics_boot, 
    df_results, 
    n_cols=0,        # number of columns in grid (set 0 for separate plots, 2 or 3 for grid)
    w_pad=0.5,       # horizontal space between columns (increase -> wider gap)
    h_pad=1.0,       # vertical space between rows (increase -> taller gap)
    shift_factor=0.0 # how much to horizontally shift last-row plots for centering
)

# %% [markdown]
# --------------------
# Gradcam ++ (more advance visualization than previous version of mine)
